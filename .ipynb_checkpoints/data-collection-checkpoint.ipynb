# %% [markdown]
# # Data Collection

# %%
import pandas as pd
import requests
import time
from bs4 import BeautifulSoup

# %% [markdown]
# ---

# %% [markdown]
# ### Results DF

# %%
results = pd.read_csv('./data/results.csv')
results.head()
# data from kaggle:  https://www.kaggle.com/martj42/international-football-results-from-1872-to-2017?select=results.csv
# Out:
#          date home_team away_team  home_score  away_score tournament     city  \
# 0  1872-11-30  Scotland   England         0.0         0.0   Friendly  Glasgow
# 1  1873-03-08   England  Scotland         4.0         2.0   Friendly   London
# 2  1874-03-07  Scotland   England         2.0         1.0   Friendly  Glasgow
# 3  1875-03-06   England  Scotland         2.0         2.0   Friendly   London
# 4  1876-03-04  Scotland   England         3.0         0.0   Friendly  Glasgow
#
#     country  neutral
# 0  Scotland    False
# 1   England    False
# 2  Scotland    False
# 3   England    False
# 4  Scotland    False

# %%
results.shape
# Out:
# (43045, 9)

# %% [markdown]
# ---

# %% [markdown]
# ### Shootout DF

# %%
shootouts = pd.read_csv('./data/shootouts.csv')
shootouts.head()
# data from kaggle:  https://www.kaggle.com/martj42/international-football-results-from-1872-to-2017?select=results.csv
# Out:
#          date    home_team         away_team       winner
# 0   8/22/1967        India            Taiwan       Taiwan
# 1  11/14/1971  South Korea  Vietnam Republic  South Korea
# 2   5/17/1972     Thailand       South Korea  South Korea
# 3   5/19/1972     Thailand          Cambodia     Thailand
# 4   7/26/1973     Malaysia            Kuwait     Malaysia

# %%
shootouts.shape
# Out:
# (432, 4)

# %% [markdown]
# ---

# %% [markdown]
# ### Upcoming Fixtures DF

# %% [markdown]
# ---

# %% [markdown]
# ### Current Table DF

# %%
url = 'https://www.fifa.com/tournaments/mens/worldcup/qatar2022/qualifiers/concacaf'
res = requests.get(url)

# %%
res.status_code
# Out:
# 200

# %%
soup = BeautifulSoup(res.content, 'lxml')

# %%
table = soup.find('table')

# %%
teams = []    
for a in soup.find_all("div", {"class": "fp-group-card_groupsTable__1cbWY"}):
    team = {}
    for row in a.find_all('tr')[1:-1]:
        team = {}
        team['name'] = row.find_all('td')[0].img.get('alt')
        team['matches_played'] = row.find_all('td')[1].text
        team['wins'] = row.find_all('td')[2].text
        team['draws'] = row.find_all('td')[3].text
        team['losses'] = row.find_all('td')[4].text
        team['goals_for'] = row.find_all('td')[5].text
        team['goals_against'] = row.find_all('td')[6].text
        team['goal_diff'] = row.find_all('td')[7].text
        team['points'] = row.find_all('td')[8].text
        
        teams.append(team)

teams
# Out:
# [{'name': 'El Salvador',
#   'matches_played': '4',
#   'wins': '3',
#   'draws': '1',
#   'losses': '0',
#   'goals_for': '13',
#   'goals_against': '1',
#   'goal_diff': '12',
#   'points': '10'},
#  {'name': 'Montserrat',
#   'matches_played': '4',
#   'wins': '2',
#   'draws': '2',
#   'losses': '0',
#   'goals_for': '9',
#   'goals_against': '4',
#   'goal_diff': '5',
#   'points': '8'},
#  {'name': 'Antigua and Barbuda',
#   'matches_played': '4',
#   'wins': '2',
#   'draws': '1',
#   'losses': '1',
#   'goals_for': '6',
#   'goals_against': '5',
#   'goal_diff': '1',
#   'points': '7'},
#  {'name': 'Grenada',
#   'matches_played': '4',
#   'wins': '1',
#   'draws': '0',
#   'losses': '3',
#   'goals_for': '2',
#   'goals_against': '5',
#   'goal_diff': '-3',
#   'points': '3'},
#  {'name': 'US Virgin Islands',
#   'matches_played': '4',
#   'wins': '0',
#   'draws': '0',
#   'losses': '4',
#   'goals_for': '0',
#   'goals_against': '15',
#   'goal_diff': '-15',
# ...

# %% [markdown]
# ---

# %% [markdown]
# ### World Rankings DF

# %%
rankings = pd.read_csv('./data/fifa_ranking-2021-05-27.csv')
rankings.head()
# data from kaggle:  https://www.kaggle.com/cashncarry/fifaworldranking
# Out:
#         id  rank         country_full country_abrv  total_points  \
# 0    43818    82                 Iraq          IRQ            15
# 1    43873   107           Mozambique          MOZ             9
# 2    43816   108            Indonesia          IDN             9
# 3  1882218   109  Antigua and Barbuda          ATG             8
# 4    43820   110               Jordan          JOR             8
#
#    previous_points  rank_change confederation   rank_date
# 0                0            0           AFC  1992-12-31
# 1                0            0           CAF  1992-12-31
# 2                0            0           AFC  1992-12-31
# 3                0            0      CONCACAF  1992-12-31
# 4                0            0           AFC  1992-12-31
