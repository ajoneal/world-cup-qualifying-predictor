# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import dataframe_image as dfi

from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split, GridSearchCV
from sklearn import metrics

from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense
from tensorflow.keras.utils import to_categorical
from tensorflow.keras.layers import Dropout
from tensorflow.keras.callbacks import EarlyStopping

# %% [markdown]
# ---

# %% [markdown]
# ## NN Model for Predicting Home Score

# %%
df = pd.read_csv('./data/cleaned_results_and_rankings.csv')
df.head(2)
# Out:
#          date home_team     away_team  home_score  away_score  neutral  \
# 0  1993-01-01     Ghana          Mali           1           1        1
# 1  1993-01-02     Gabon  Burkina Faso           1           1        0
#
#    home_rank  away_rank  h_goals_for_avg  h_goals_against_avg  \
# 0         39         69              0.0                  0.0
# 1         55         97              0.0                  0.0
#
#    a_goals_for_avg  a_goals_against_avg    datetime  match_type_FIFA_WCQ  \
# 0              0.0                  0.0  1993-01-01                    0
# 1              0.0                  0.0  1993-01-02                    0
#
#    match_type_Friendly  match_type_Qualifier  match_type_Tournament/Cup_Match
# 0                    1                     0                                0
# 1                    1                     0                                0

# %%
features = ['neutral', 'home_rank', 'away_rank', 'h_goals_for_avg', 'h_goals_against_avg', 'a_goals_for_avg', 'a_goals_against_avg', 'match_type_FIFA_WCQ', 'match_type_Friendly', 'match_type_Qualifier', 'match_type_Tournament/Cup_Match']
X = df[features]
y = df['home_score']

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=42)

# %%
ss = StandardScaler()
ss.fit(X_train, y_train)
X_train_sc = ss.transform(X_train)
X_test_sc = ss.transform(X_test)

# %%
home_model = Sequential()

home_model.add(Dense(32, activation='relu', input_shape=(11,)))
home_model.add(Dense(32, activation='relu'))
home_model.add(Dense(32, activation='relu'))
home_model.add(Dense(1, activation=None))

home_model.compile(loss='mse', optimizer='adam')

# %%
home_model.fit(X_train_sc, y_train,
               batch_size=512,
               epochs=100,
               validation_data=(X_test_sc, y_test),
               verbose=0)

# %%
home_score_preds = home_model.predict(X_test_sc).round().astype(int)
home_score_preds = [i for sublist in home_score_preds for i in sublist]
# home_score_preds

# %%
metrics.r2_score(y_test, home_score_preds)
# Out:
# 0.18064372128244988

# %%
# on average, home score predictions are 1 goal off
metrics.mean_absolute_error(y_test, home_score_preds)
# Out:
# 1.0

# %% [markdown]
# ---

# %% [markdown]
# ## NN Model for Predicting Away Score

# %%
features = ['neutral', 'home_rank', 'away_rank', 'h_goals_for_avg', 'h_goals_against_avg', 'a_goals_for_avg',
            'a_goals_against_avg', 'match_type_FIFA_WCQ', 'match_type_Friendly', 'match_type_Qualifier',
            'match_type_Tournament/Cup_Match']
X = df[features]
y = df['away_score']

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=42)

# %%
ss = StandardScaler()
ss.fit(X_train, y_train)
X_train_sc = ss.transform(X_train)
X_test_sc = ss.transform(X_test)

# %%
away_model = Sequential()

away_model.add(Dense(32, activation='relu', input_shape=(11,)))
away_model.add(Dense(32, activation='relu'))
away_model.add(Dense(32, activation='relu'))
away_model.add(Dense(1, activation=None))

away_model.compile(loss='mse', optimizer='adam')

# %%
away_model.fit(X_train_sc, y_train,
               batch_size=512,
               epochs=100,
               validation_data=(X_test_sc, y_test),
               verbose=0)

# %%
away_score_preds = away_model.predict(X_test_sc).round().astype(int)
away_score_preds = [i for sublist in away_score_preds for i in sublist]
# away_score_preds

# %%
# 11% of predicted away scores can be explained by the model
metrics.r2_score(y_test, away_score_preds)
# Out:
# 0.10618349305798258

# %%
# on average, away score predictions are less than one goal off
metrics.mean_absolute_error(y_test, away_score_preds)
# Out:
# 0.8097535757366879

# %% [markdown]
# ---

# %% [markdown]
# ## Predicting Upcoming Fixtures

# %%
qualifying_fixtures = pd.read_csv('./data/cleaned_qualifying_fixtures.csv')
qualifying_fixtures.drop(columns=['home_score', 'away_score'], inplace=True)
qualifying_fixtures.head(2)
# Out:
#          date home_team   away_team  neutral  home_rank  away_rank  \
# 0  2021-09-02    Canada    Honduras        0         59         63
# 1  2021-09-02    Panama  Costa Rica        0         74         44
#
#    h_goals_for_avg  h_goals_against_avg  a_goals_for_avg  a_goals_against_avg  \
# 0              3.2                  0.2              1.1                  1.9
# 1              2.4                  1.1              0.9                  1.3
#
#      datetime  match_type_FIFA_WCQ  match_type_Friendly  match_type_Qualifier  \
# 0  2021-09-02                    1                    0                     0
# 1  2021-09-02                    1                    0                     0
#
#    match_type_Tournament/Cup_Match
# 0                                0
# 1                                0

# %%
features = ['neutral', 'home_rank', 'away_rank', 'h_goals_for_avg', 'h_goals_against_avg', 'a_goals_for_avg',
            'a_goals_against_avg', 'match_type_FIFA_WCQ', 'match_type_Friendly', 'match_type_Qualifier',
            'match_type_Tournament/Cup_Match']
X = qualifying_fixtures[features]

# %%
X_sc = ss.fit_transform(X)

# %%
home_score_preds = home_model.predict(X_sc).round().astype(int)
home_score_preds = [i for sublist in home_score_preds for i in sublist]
# home_score_preds

# %%
qualifying_fixtures['home_score'] = home_score_preds

# %%
away_score_preds = away_model.predict(X_sc).round().astype(int)
away_score_preds = [i for sublist in away_score_preds for i in sublist]
# away_score_preds

# %%
qualifying_fixtures['away_score'] = away_score_preds

# %%
CONCACAF_fixture_predictions = qualifying_fixtures[['date', 'home_rank', 'home_team', 'home_score', 'away_score', 'away_team', 'away_rank']]
CONCACAF_fixture_predictions
# Out:
#           date  home_rank      home_team  home_score  away_score  \
# 0   2021-09-02         59         Canada           2           0
# 1   2021-09-02         74         Panama           1           1
# 2   2021-09-02          9         Mexico           3           0
# 3   2021-09-02         64    El Salvador           0           2
# 4   2021-09-05         50        Jamaica           2           0
# 5   2021-09-05         64    El Salvador           2           0
# 6   2021-09-05         44     Costa Rica           1           2
# 7   2021-09-05         10  United States           2           0
# 8   2021-09-08         59         Canada           2           0
# 9   2021-09-08         74         Panama           1           3
# 10  2021-09-08         44     Costa Rica           1           1
# 11  2021-09-08         63       Honduras           0           2
# 12  2021-10-07         63       Honduras           1           1
# 13  2021-10-07         10  United States           3           1
# 14  2021-10-07          9         Mexico           2           0
# 15  2021-10-07         64    El Salvador           1           0
# 16  2021-10-10         50        Jamaica           1           1
# 17  2021-10-10         74         Panama           1           2
# 18  2021-10-10         44     Costa Rica           1           1
# 19  2021-10-10          9         Mexico           4           0
# 20  2021-10-12         10  United States           2           0
# 21  2021-10-13         59         Canada           2           0
# 22  2021-10-13         63       Honduras           1           1
# 23  2021-10-13         64    El Salvador           0           2
# 24  2021-11-11         10  United States           1           1
# 25  2021-11-12         63       Honduras           2           0
# 26  2021-11-12         64    El Salvador           1           1
# 27  2021-11-12         59         Canada           1           1
# 28  2021-11-16         50        Jamaica           1           1
# 29  2021-11-16         74         Panama           1           1
# 30  2021-11-16         44     Costa Rica           2           1
# 31  2021-11-16         59         Canada           0           2
# 32  2022-01-26         50        Jamaica           0           2
# 33  2022-01-26         63       Honduras           1           1
# 34  2022-01-26         10  United States           3           0
# 35  2022-01-26         44     Costa Rica           2           1
# 36  2022-01-29         63       Honduras           1           0
# 37  2022-01-29         74         Panama           1           2
# 38  2022-01-29         59         Canada           0           2
# 39  2022-01-29          9         Mexico           2           0
# 40  2022-02-01         50        Jamaica           1           1
# 41  2022-02-01         10  United States           3           0
# 42  2022-02-01          9         Mexico           4           0
# 43  2022-02-01         64    El Salvador           1           1
# 44  2022-03-23         50        Jamaica           1           0
# 45  2022-03-23         74         Panama           1           1
# 46  2022-03-23          9         Mexico           1           1
# 47  2022-03-23         44     Costa Rica           1           1
# 48  2022-03-26         10  United States           3           0
# 49  2022-03-26         63       Honduras           0           2
# 50  2022-03-26         64    El Salvador           1           1
# 51  2022-03-26         59         Canada           1           1
# 52  2022-03-29          9         Mexico           3           0
# 53  2022-03-29         50        Jamaica           2           0
# 54  2022-03-29         74         Panama           1           1
# 55  2022-03-29         44     Costa Rica           1           1
#
#         away_team  away_rank
# 0        Honduras         63
# 1      Costa Rica         44
# 2         Jamaica         50
# 3   United States         10
# 4          Panama         74
# 5        Honduras         63
# 6          Mexico          9
# 7          Canada         59
# 8     El Salvador         64
# 9          Mexico          9
# 10        Jamaica         50
# 11  United States         10
# 12     Costa Rica         44
# 13        Jamaica         50
# 14         Canada         59
# 15         Panama         74
# 16         Canada         59
# 17  United States         10
# 18    El Salvador         64
# 19       Honduras         63
# 20     Costa Rica         44
# 21         Panama         74
# 22        Jamaica         50
# 23         Mexico          9
# 24         Mexico          9
# 25         Panama         74
# 26        Jamaica         50
# 27     Costa Rica         44
# 28  United States         10
# 29    El Salvador         64
# 30       Honduras         63
# 31         Mexico          9
# 32         Mexico          9
# 33         Canada         59
# 34    El Salvador         64
# 35         Panama         74
# 36    El Salvador         64
# 37        Jamaica         50
# 38  United States         10
# 39     Costa Rica         44
# 40     Costa Rica         44
# 41       Honduras         63
# 42         Panama         74
# 43         Canada         59
# 44    El Salvador         64
# 45       Honduras         63
# 46  United States         10
# 47         Canada         59
# 48         Panama         74
# 49         Mexico          9
# 50     Costa Rica         44
# 51        Jamaica         50
# 52    El Salvador         64
# 53       Honduras         63
# 54         Canada         59
# 55  United States         10

# %%
dfi.export(CONCACAF_fixture_predictions, './images/CONCACAF_fixture_predictions.png')

# %%
qualifying_fixtures.to_csv('./data/qualifier_predictions.csv', index=False)
