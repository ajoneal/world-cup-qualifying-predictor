# %% [markdown]
# # Predicting CONCACAF WCQ table

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import dataframe_image as dfi

# %%
current_CONCACAF_table = pd.read_csv('./data/current_table_12.14.2021.csv')
current_CONCACAF_table
# Out:
#    rank    team_name  matches_played  wins  draws  losses  goals_for  \
# 0     1       Canada               8     4      4       0         13
# 1     2          USA               8     4      3       1         12
# 2     3       Mexico               8     4      2       2         11
# 3     4       Panama               8     4      2       2         11
# 4     5   Costa Rica               8     2      3       3          6
# 5     6      Jamaica               8     1      4       3          6
# 6     7  El Salvador               8     1      3       4          4
# 7     8     Honduras               8     0      3       5          5
#
#    goals_against  goal_differential  points
# 0              5                  8      16
# 1              5                  7      15
# 2              7                  4      14
# 3              9                  2      14
# 4              7                 -1       9
# 5             10                 -4       7
# 6             10                 -6       6
# 7             15                -10       3

# %%
dfi.export(current_CONCACAF_table, './images/current_table.png')

# %%
# creating new table for predictions

predictions_dict = {'team_name': ['Canada', 'United States', 'Mexico', 'Panama', 'Costa Rica', 'Jamaica', 'El Salvador', 'Honduras'], 
'matches_played': [0, 0, 0, 0, 0, 0, 0, 0], 'wins': [0, 0, 0, 0, 0, 0, 0, 0], 'draws': [0, 0, 0, 0, 0, 0, 0, 0],
'losses': [0, 0, 0, 0, 0, 0, 0, 0], 'goals_for': [0, 0, 0, 0, 0, 0, 0, 0], 'goals_against': [0, 0, 0, 0, 0, 0, 0, 0], 
'goal_differential': [0, 0, 0, 0, 0, 0, 0, 0], 'points': [0, 0, 0, 0, 0, 0, 0, 0]}

predicted_table = pd.DataFrame(predictions_dict)
predicted_table
# Out:
#        team_name  matches_played  wins  draws  losses  goals_for  \
# 0         Canada               0     0      0       0          0
# 1  United States               0     0      0       0          0
# 2         Mexico               0     0      0       0          0
# 3         Panama               0     0      0       0          0
# 4     Costa Rica               0     0      0       0          0
# 5        Jamaica               0     0      0       0          0
# 6    El Salvador               0     0      0       0          0
# 7       Honduras               0     0      0       0          0
#
#    goals_against  goal_differential  points
# 0              0                  0       0
# 1              0                  0       0
# 2              0                  0       0
# 3              0                  0       0
# 4              0                  0       0
# 5              0                  0       0
# 6              0                  0       0
# 7              0                  0       0

# %%
qualifying_predictions = pd.read_csv('./data/qualifier_predictions.csv')
# qualifying_fixtures

# %%
qualifying_predictions_dict = qualifying_predictions.to_dict('records')
# qualifying_fixtures_dict[0]

predicted_table_dict = predicted_table.to_dict('records')
# predicted_table_dict[0]

# %%
# Updating predictions table with predictions for qualifying matches

for i in qualifying_predictions_dict:
    for j in predicted_table_dict:
        if i['home_team'] == j['team_name']:
            j['matches_played'] = j['matches_played'] + 1
            j['goals_for'] = j['goals_for'] + i['home_score']
            j['goals_against'] = j['goals_against'] + i['away_score']
            j['goal_differential'] = j['goal_differential'] + i['home_score'] - i['away_score']
            if i['home_score'] > i['away_score']:
                j['wins'] = j['wins'] + 1
                j['points'] = j['points'] + 3
            elif i['home_score'] == i['away_score']:
                j['draws'] = j['draws'] + 1
                j['points'] = j['points'] + 1
            elif i['home_score'] < i['away_score']:
                j['losses'] = j['losses'] + 1
    
# pd.DataFrame(predicted_table_dict)

for i in qualifying_predictions_dict:
    for j in predicted_table_dict:
        if i['away_team'] == j['team_name']:
            j['matches_played'] = j['matches_played'] + 1
            j['goals_for'] = j['goals_for'] + i['away_score']
            j['goals_against'] = j['goals_against'] + i['home_score']
            j['goal_differential'] = j['goal_differential'] + i['away_score'] - i['home_score']
            if i['away_score'] > i['home_score']:
                j['wins'] = j['wins'] + 1
                j['points'] = j['points'] + 3
            elif i['away_score'] == i['home_score']:
                j['draws'] = j['draws'] + 1
                j['points'] = j['points'] + 1
            elif i['away_score'] < i['home_score']:
                j['losses'] = j['losses'] + 1
    
predicted_table = pd.DataFrame(predicted_table_dict)
predicted_table
# Out:
#        team_name  matches_played  wins  draws  losses  goals_for  \
# 0         Canada              14     3      7       4         13
# 1  United States              14    10      4       0         28
# 2         Mexico              14    12      2       0         33
# 3         Panama              14     0      4      10          8
# 4     Costa Rica              14     2      9       3         14
# 5        Jamaica              14     4      7       3         15
# 6    El Salvador              14     2      5       7          8
# 7       Honduras              14     2      4       8          8
#
#    goals_against  goal_differential  points
# 0             15                 -2      16
# 1              6                 22      34
# 2              4                 29      38
# 3             27                -19       4
# 4             17                 -3      15
# 5             16                 -1      19
# 6             19                -11      11
# 7             23                -15      10

# %%
predicted_table = predicted_table.reindex(predicted_table.sort_values(['points', 'goal_differential', 'goals_for'], ascending=[False, False, False]).index)
predicted_table.reset_index(inplace=True)

predicted_table.rename(columns={'index': 'rank'}, inplace=True)
predicted_table['rank'] = list(range(1,9))
predicted_table.set_index(predicted_table['rank'], inplace=True)
predicted_table.drop(columns=['rank'], inplace=True)
predicted_table
# Out:
#           team_name  matches_played  wins  draws  losses  goals_for  \
# rank
# 1            Mexico              14    12      2       0         33
# 2     United States              14    10      4       0         28
# 3           Jamaica              14     4      7       3         15
# 4            Canada              14     3      7       4         13
# 5        Costa Rica              14     2      9       3         14
# 6       El Salvador              14     2      5       7          8
# 7          Honduras              14     2      4       8          8
# 8            Panama              14     0      4      10          8
#
#       goals_against  goal_differential  points
# rank
# 1                 4                 29      38
# 2                 6                 22      34
# 3                16                 -1      19
# 4                15                 -2      16
# 5                17                 -3      15
# 6                19                -11      11
# 7                23                -15      10
# 8                27                -19       4

# %%
dfi.export(predicted_table, './images/predicted_table.png')

# %% [markdown]
# ---

# %% [markdown]
# # Checking predictions against qualifier results

# %% [markdown]
# ### All predictions

# %%
qualifying_fixtures = pd.read_csv('./data/concacaf_wcq_fixtures.csv')
qualifying_fixtures = qualifying_fixtures[['date', 'home_team', 'home_score', 'away_score', 'away_team']].head(32)
qualifying_fixtures['home_score'] = qualifying_fixtures['home_score'].astype(int)
qualifying_fixtures['away_score'] = qualifying_fixtures['away_score'].astype(int)
qualifying_fixtures
# Out:
#           date      home_team  home_score  away_score      away_team
# 0   2021-09-02         Canada           1           1       Honduras
# 1   2021-09-02         Panama           0           0     Costa Rica
# 2   2021-09-02         Mexico           2           1        Jamaica
# 3   2021-09-02    El Salvador           0           0  United States
# 4   2021-09-05        Jamaica           0           3         Panama
# 5   2021-09-05    El Salvador           0           0       Honduras
# 6   2021-09-05     Costa Rica           0           1         Mexico
# 7   2021-09-05  United States           1           1         Canada
# 8   2021-09-08         Canada           3           0    El Salvador
# 9   2021-09-08         Panama           1           1         Mexico
# 10  2021-09-08     Costa Rica           1           1        Jamaica
# 11  2021-09-08       Honduras           1           4  United States
# 12  2021-10-07       Honduras           0           0     Costa Rica
# 13  2021-10-07  United States           2           0        Jamaica
# 14  2021-10-07         Mexico           1           1         Canada
# 15  2021-10-07    El Salvador           1           0         Panama
# 16  2021-10-10        Jamaica           0           0         Canada
# 17  2021-10-10         Panama           1           0  United States
# 18  2021-10-10     Costa Rica           2           1    El Salvador
# 19  2021-10-10         Mexico           3           0       Honduras
# 20  2021-10-12  United States           2           1     Costa Rica
# 21  2021-10-13         Canada           4           1         Panama
# 22  2021-10-13       Honduras           0           2        Jamaica
# 23  2021-10-13    El Salvador           0           2         Mexico
# 24  2021-11-11  United States           2           0         Mexico
# 25  2021-11-12       Honduras           2           3         Panama
# 26  2021-11-12    El Salvador           1           1        Jamaica
# 27  2021-11-12         Canada           1           0     Costa Rica
# 28  2021-11-16        Jamaica           1           1  United States
# 29  2021-11-16         Panama           2           1    El Salvador
# 30  2021-11-16     Costa Rica           2           1       Honduras
# 31  2021-11-16         Canada           2           1         Mexico

# %%
qualifying_predictions = qualifying_predictions[['home_team', 'home_score', 'away_score', 'away_team', 'date']]
qualifying_predictions.rename(columns={'home_team': 'preds_home_team', 'home_score': 'preds_home_score',
                                      'away_score': 'preds_away_score', 'away_team': 'preds_away_team', 
                                       'date': 'preds_date'}, inplace=True)

# %%
real_vs_pred = pd.concat([qualifying_fixtures, qualifying_predictions], axis=1)
real_vs_pred = real_vs_pred.head(32)
real_vs_pred
# Out:
#           date      home_team  home_score  away_score      away_team  \
# 0   2021-09-02         Canada         1.0         1.0       Honduras
# 1   2021-09-02         Panama         0.0         0.0     Costa Rica
# 2   2021-09-02         Mexico         2.0         1.0        Jamaica
# 3   2021-09-02    El Salvador         0.0         0.0  United States
# 4   2021-09-05        Jamaica         0.0         3.0         Panama
# 5   2021-09-05    El Salvador         0.0         0.0       Honduras
# 6   2021-09-05     Costa Rica         0.0         1.0         Mexico
# 7   2021-09-05  United States         1.0         1.0         Canada
# 8   2021-09-08         Canada         3.0         0.0    El Salvador
# 9   2021-09-08         Panama         1.0         1.0         Mexico
# 10  2021-09-08     Costa Rica         1.0         1.0        Jamaica
# 11  2021-09-08       Honduras         1.0         4.0  United States
# 12  2021-10-07       Honduras         0.0         0.0     Costa Rica
# 13  2021-10-07  United States         2.0         0.0        Jamaica
# 14  2021-10-07         Mexico         1.0         1.0         Canada
# 15  2021-10-07    El Salvador         1.0         0.0         Panama
# 16  2021-10-10        Jamaica         0.0         0.0         Canada
# 17  2021-10-10         Panama         1.0         0.0  United States
# 18  2021-10-10     Costa Rica         2.0         1.0    El Salvador
# 19  2021-10-10         Mexico         3.0         0.0       Honduras
# 20  2021-10-12  United States         2.0         1.0     Costa Rica
# 21  2021-10-13         Canada         4.0         1.0         Panama
# 22  2021-10-13       Honduras         0.0         2.0        Jamaica
# 23  2021-10-13    El Salvador         0.0         2.0         Mexico
# 24  2021-11-11  United States         2.0         0.0         Mexico
# 25  2021-11-12       Honduras         2.0         3.0         Panama
# 26  2021-11-12    El Salvador         1.0         1.0        Jamaica
# 27  2021-11-12         Canada         1.0         0.0     Costa Rica
# 28  2021-11-16        Jamaica         1.0         1.0  United States
# 29  2021-11-16         Panama         2.0         1.0    El Salvador
# 30  2021-11-16     Costa Rica         2.0         1.0       Honduras
# 31  2021-11-16         Canada         2.0         1.0         Mexico
#
#    preds_home_team  preds_home_score  preds_away_score preds_away_team  \
# 0           Canada                 2                 0        Honduras
# 1           Panama                 1                 1      Costa Rica
# 2           Mexico                 3                 0         Jamaica
# 3      El Salvador                 0                 2   United States
# 4          Jamaica                 2                 0          Panama
# 5      El Salvador                 2                 0        Honduras
# 6       Costa Rica                 1                 2          Mexico
# 7    United States                 2                 0          Canada
# 8           Canada                 2                 0     El Salvador
# 9           Panama                 1                 3          Mexico
# 10      Costa Rica                 1                 1         Jamaica
# 11        Honduras                 0                 2   United States
# 12        Honduras                 1                 1      Costa Rica
# 13   United States                 3                 1         Jamaica
# 14          Mexico                 2                 0          Canada
# 15     El Salvador                 1                 0          Panama
# 16         Jamaica                 1                 1          Canada
# 17          Panama                 1                 2   United States
# 18      Costa Rica                 1                 1     El Salvador
# 19          Mexico                 4                 0        Honduras
# 20   United States                 2                 0      Costa Rica
# 21          Canada                 2                 0          Panama
# 22        Honduras                 1                 1         Jamaica
# 23     El Salvador                 0                 2          Mexico
# 24   United States                 1                 1          Mexico
# 25        Honduras                 2                 0          Panama
# 26     El Salvador                 1                 1         Jamaica
# 27          Canada                 1                 1      Costa Rica
# 28         Jamaica                 1                 1   United States
# 29          Panama                 1                 1     El Salvador
# 30      Costa Rica                 2                 1        Honduras
# 31          Canada                 0                 2          Mexico
#
#     preds_date
# 0   2021-09-02
# 1   2021-09-02
# 2   2021-09-02
# 3   2021-09-02
# 4   2021-09-05
# 5   2021-09-05
# 6   2021-09-05
# 7   2021-09-05
# 8   2021-09-08
# 9   2021-09-08
# 10  2021-09-08
# 11  2021-09-08
# 12  2021-10-07
# 13  2021-10-07
# 14  2021-10-07
# 15  2021-10-07
# 16  2021-10-10
# 17  2021-10-10
# 18  2021-10-10
# 19  2021-10-10
# 20  2021-10-12
# 21  2021-10-13
# 22  2021-10-13
# 23  2021-10-13
# 24  2021-11-11
# 25  2021-11-12
# 26  2021-11-12
# 27  2021-11-12
# 28  2021-11-16
# 29  2021-11-16
# 30  2021-11-16
# 31  2021-11-16

# %%
dfi.export(real_vs_pred, './images/actual_vs_predicted.png')

# %%
# 6 correct home and away score predictions in 32 matches (18.75%)
# 17 correct predictions of outcome in 32 matches (53.13%)
# 12 correct predictions of home team score (37.50%)
# 11 correct predictions of away team score (34.38%)
# 12 correct predictions of total goals scored (37.50%)

# %% [markdown]
# ---

# %% [markdown]
# ## Predictions by team

# %% [markdown]
# ### Mexico

# %%
real_vs_pred[(real_vs_pred['home_team'] == 'Mexico') | (real_vs_pred['away_team'] == 'Mexico')]
# Out:
#           date      home_team  home_score  away_score away_team  \
# 2   2021-09-02         Mexico         2.0         1.0   Jamaica
# 6   2021-09-05     Costa Rica         0.0         1.0    Mexico
# 9   2021-09-08         Panama         1.0         1.0    Mexico
# 14  2021-10-07         Mexico         1.0         1.0    Canada
# 19  2021-10-10         Mexico         3.0         0.0  Honduras
# 23  2021-10-13    El Salvador         0.0         2.0    Mexico
# 24  2021-11-11  United States         2.0         0.0    Mexico
# 31  2021-11-16         Canada         2.0         1.0    Mexico
#
#    preds_home_team  preds_home_score  preds_away_score preds_away_team  \
# 2           Mexico                 3                 0         Jamaica
# 6       Costa Rica                 1                 2          Mexico
# 9           Panama                 1                 3          Mexico
# 14          Mexico                 2                 0          Canada
# 19          Mexico                 4                 0        Honduras
# 23     El Salvador                 0                 2          Mexico
# 24   United States                 1                 1          Mexico
# 31          Canada                 0                 2          Mexico
#
#     preds_date
# 2   2021-09-02
# 6   2021-09-05
# 9   2021-09-08
# 14  2021-10-07
# 19  2021-10-10
# 23  2021-10-13
# 24  2021-11-11
# 31  2021-11-16

# %%
# 1 correct home and away score predictions in (12.5%)
# 4 correct predictions of outcome in (50%)
# 1 correct predictions of home team score (12.5%)
# 2 correct predictions of away team score (25%)
# 4 correct predictions of total goals scored (50%)

# %% [markdown]
# ---

# %% [markdown]
# ### United States

# %%
real_vs_pred[(real_vs_pred['home_team'] == 'United States') | (real_vs_pred['away_team'] == 'United States')]
# Out:
#           date      home_team  home_score  away_score      away_team  \
# 3   2021-09-02    El Salvador         0.0         0.0  United States
# 7   2021-09-05  United States         1.0         1.0         Canada
# 11  2021-09-08       Honduras         1.0         4.0  United States
# 13  2021-10-07  United States         2.0         0.0        Jamaica
# 17  2021-10-10         Panama         1.0         0.0  United States
# 20  2021-10-12  United States         2.0         1.0     Costa Rica
# 24  2021-11-11  United States         2.0         0.0         Mexico
# 28  2021-11-16        Jamaica         1.0         1.0  United States
#
#    preds_home_team  preds_home_score  preds_away_score preds_away_team  \
# 3      El Salvador                 0                 2   United States
# 7    United States                 2                 0          Canada
# 11        Honduras                 0                 2   United States
# 13   United States                 3                 1         Jamaica
# 17          Panama                 1                 2   United States
# 20   United States                 2                 0      Costa Rica
# 24   United States                 1                 1          Mexico
# 28         Jamaica                 1                 1   United States
#
#     preds_date
# 3   2021-09-02
# 7   2021-09-05
# 11  2021-09-08
# 13  2021-10-07
# 17  2021-10-10
# 20  2021-10-12
# 24  2021-11-11
# 28  2021-11-16

# %%
# 1 correct home and away score predictions in (12.5%)
# 4 correct predictions of outcome in (50%)
# 4 correct predictions of home team score (50%)
# 1 correct predictions of away team score (12.5%)
# 3 correct predictions of total goals scored (37.5%)

# %% [markdown]
# ---

# %% [markdown]
# ### Jamaica

# %%
real_vs_pred[(real_vs_pred['home_team'] == 'Jamaica') | (real_vs_pred['away_team'] == 'Jamaica')]
# Out:
#           date      home_team  home_score  away_score      away_team  \
# 2   2021-09-02         Mexico         2.0         1.0        Jamaica
# 4   2021-09-05        Jamaica         0.0         3.0         Panama
# 10  2021-09-08     Costa Rica         1.0         1.0        Jamaica
# 13  2021-10-07  United States         2.0         0.0        Jamaica
# 16  2021-10-10        Jamaica         0.0         0.0         Canada
# 22  2021-10-13       Honduras         0.0         2.0        Jamaica
# 26  2021-11-12    El Salvador         1.0         1.0        Jamaica
# 28  2021-11-16        Jamaica         1.0         1.0  United States
#
#    preds_home_team  preds_home_score  preds_away_score preds_away_team  \
# 2           Mexico                 3                 0         Jamaica
# 4          Jamaica                 2                 0          Panama
# 10      Costa Rica                 1                 1         Jamaica
# 13   United States                 3                 1         Jamaica
# 16         Jamaica                 1                 1          Canada
# 22        Honduras                 1                 1         Jamaica
# 26     El Salvador                 1                 1         Jamaica
# 28         Jamaica                 1                 1   United States
#
#     preds_date
# 2   2021-09-02
# 4   2021-09-05
# 10  2021-09-08
# 13  2021-10-07
# 16  2021-10-10
# 22  2021-10-13
# 26  2021-11-12
# 28  2021-11-16

# %%
# 3 correct home and away score predictions in (37.5%)
# 6 correct predictions of outcome in (75%)
# 3 correct predictions of home team score (37.5%)
# 3 correct predictions of away team score (37.5%)
# 5 correct predictions of total goals scored (62.5%)

# %% [markdown]
# ---

# %% [markdown]
# ### Canada

# %%
real_vs_pred[(real_vs_pred['home_team'] == 'Canada') | (real_vs_pred['away_team'] == 'Canada')]
# Out:
#           date      home_team  home_score  away_score    away_team  \
# 0   2021-09-02         Canada         1.0         1.0     Honduras
# 7   2021-09-05  United States         1.0         1.0       Canada
# 8   2021-09-08         Canada         3.0         0.0  El Salvador
# 14  2021-10-07         Mexico         1.0         1.0       Canada
# 16  2021-10-10        Jamaica         0.0         0.0       Canada
# 21  2021-10-13         Canada         4.0         1.0       Panama
# 27  2021-11-12         Canada         1.0         0.0   Costa Rica
# 31  2021-11-16         Canada         2.0         1.0       Mexico
#
#    preds_home_team  preds_home_score  preds_away_score preds_away_team  \
# 0           Canada                 2                 0        Honduras
# 7    United States                 2                 0          Canada
# 8           Canada                 2                 0     El Salvador
# 14          Mexico                 2                 0          Canada
# 16         Jamaica                 1                 1          Canada
# 21          Canada                 2                 0          Panama
# 27          Canada                 1                 1      Costa Rica
# 31          Canada                 0                 2          Mexico
#
#     preds_date
# 0   2021-09-02
# 7   2021-09-05
# 8   2021-09-08
# 14  2021-10-07
# 16  2021-10-10
# 21  2021-10-13
# 27  2021-11-12
# 31  2021-11-16

# %%
# 0 correct home and away score predictions in (0%)
# 3 correct predictions of outcome in (37.5%)
# 1 correct predictions of home team score (12.5%)
# 1 correct predictions of away team score (12.5%)
# 3 correct predictions of total goals scored (37.5%)

# %% [markdown]
# ---

# %% [markdown]
# ### Costa Rica

# %%
real_vs_pred[(real_vs_pred['home_team'] == 'Costa Rica') | (real_vs_pred['away_team'] == 'Costa Rica')]
# Out:
#           date      home_team  home_score  away_score    away_team  \
# 1   2021-09-02         Panama         0.0         0.0   Costa Rica
# 6   2021-09-05     Costa Rica         0.0         1.0       Mexico
# 10  2021-09-08     Costa Rica         1.0         1.0      Jamaica
# 12  2021-10-07       Honduras         0.0         0.0   Costa Rica
# 18  2021-10-10     Costa Rica         2.0         1.0  El Salvador
# 20  2021-10-12  United States         2.0         1.0   Costa Rica
# 27  2021-11-12         Canada         1.0         0.0   Costa Rica
# 30  2021-11-16     Costa Rica         2.0         1.0     Honduras
#
#    preds_home_team  preds_home_score  preds_away_score preds_away_team  \
# 1           Panama                 1                 1      Costa Rica
# 6       Costa Rica                 1                 2          Mexico
# 10      Costa Rica                 1                 1         Jamaica
# 12        Honduras                 1                 1      Costa Rica
# 18      Costa Rica                 1                 1     El Salvador
# 20   United States                 2                 0      Costa Rica
# 27          Canada                 1                 1      Costa Rica
# 30      Costa Rica                 2                 1        Honduras
#
#     preds_date
# 1   2021-09-02
# 6   2021-09-05
# 10  2021-09-08
# 12  2021-10-07
# 18  2021-10-10
# 20  2021-10-12
# 27  2021-11-12
# 30  2021-11-16

# %%
# 2 correct home and away score predictions in (25%)
# 6 correct predictions of outcome in (75%)
# 4 correct predictions of home team score (50%)
# 3 correct predictions of away team score (37.5%)
# 2 correct predictions of total goals scored (25%)

# %% [markdown]
# ---

# %% [markdown]
# ### El Salvador

# %%
real_vs_pred[(real_vs_pred['home_team'] == 'El Salvador') | (real_vs_pred['away_team'] == 'El Salvador')]
# Out:
#           date    home_team  home_score  away_score      away_team  \
# 3   2021-09-02  El Salvador         0.0         0.0  United States
# 5   2021-09-05  El Salvador         0.0         0.0       Honduras
# 8   2021-09-08       Canada         3.0         0.0    El Salvador
# 15  2021-10-07  El Salvador         1.0         0.0         Panama
# 18  2021-10-10   Costa Rica         2.0         1.0    El Salvador
# 23  2021-10-13  El Salvador         0.0         2.0         Mexico
# 26  2021-11-12  El Salvador         1.0         1.0        Jamaica
# 29  2021-11-16       Panama         2.0         1.0    El Salvador
#
#    preds_home_team  preds_home_score  preds_away_score preds_away_team  \
# 3      El Salvador                 0                 2   United States
# 5      El Salvador                 2                 0        Honduras
# 8           Canada                 2                 0     El Salvador
# 15     El Salvador                 1                 0          Panama
# 18      Costa Rica                 1                 1     El Salvador
# 23     El Salvador                 0                 2          Mexico
# 26     El Salvador                 1                 1         Jamaica
# 29          Panama                 1                 1     El Salvador
#
#     preds_date
# 3   2021-09-02
# 5   2021-09-05
# 8   2021-09-08
# 15  2021-10-07
# 18  2021-10-10
# 23  2021-10-13
# 26  2021-11-12
# 29  2021-11-16

# %%
# 3 correct home and away score predictions in (37.5%)
# 4 correct predictions of outcome in (50%)
# 4 correct predictions of home team score (50%)
# 7 correct predictions of away team score (87.5%)
# 3 correct predictions of total goals scored (37.5%)

# %% [markdown]
# ---

# %% [markdown]
# ### Honduras

# %%
real_vs_pred[(real_vs_pred['home_team'] == 'Honduras') | (real_vs_pred['away_team'] == 'Honduras')]
# Out:
#           date    home_team  home_score  away_score      away_team  \
# 0   2021-09-02       Canada         1.0         1.0       Honduras
# 5   2021-09-05  El Salvador         0.0         0.0       Honduras
# 11  2021-09-08     Honduras         1.0         4.0  United States
# 12  2021-10-07     Honduras         0.0         0.0     Costa Rica
# 19  2021-10-10       Mexico         3.0         0.0       Honduras
# 22  2021-10-13     Honduras         0.0         2.0        Jamaica
# 25  2021-11-12     Honduras         2.0         3.0         Panama
# 30  2021-11-16   Costa Rica         2.0         1.0       Honduras
#
#    preds_home_team  preds_home_score  preds_away_score preds_away_team  \
# 0           Canada                 2                 0        Honduras
# 5      El Salvador                 2                 0        Honduras
# 11        Honduras                 0                 2   United States
# 12        Honduras                 1                 1      Costa Rica
# 19          Mexico                 4                 0        Honduras
# 22        Honduras                 1                 1         Jamaica
# 25        Honduras                 2                 0          Panama
# 30      Costa Rica                 2                 1        Honduras
#
#     preds_date
# 0   2021-09-02
# 5   2021-09-05
# 11  2021-09-08
# 12  2021-10-07
# 19  2021-10-10
# 22  2021-10-13
# 25  2021-11-12
# 30  2021-11-16

# %%
# 1 correct home and away score predictions in (12.5%)
# 4 correct predictions of outcome in (50%)
# 2 correct predictions of home team score (25%)
# 3 correct predictions of away team score (37.5%)
# 3 correct predictions of total goals scored (37.5%)

# %% [markdown]
# ---

# %% [markdown]
# ### Panama

# %%
real_vs_pred[(real_vs_pred['home_team'] == 'Panama') | (real_vs_pred['away_team'] == 'Panama')]
# Out:
#           date    home_team  home_score  away_score      away_team  \
# 1   2021-09-02       Panama         0.0         0.0     Costa Rica
# 4   2021-09-05      Jamaica         0.0         3.0         Panama
# 9   2021-09-08       Panama         1.0         1.0         Mexico
# 15  2021-10-07  El Salvador         1.0         0.0         Panama
# 17  2021-10-10       Panama         1.0         0.0  United States
# 21  2021-10-13       Canada         4.0         1.0         Panama
# 25  2021-11-12     Honduras         2.0         3.0         Panama
# 29  2021-11-16       Panama         2.0         1.0    El Salvador
#
#    preds_home_team  preds_home_score  preds_away_score preds_away_team  \
# 1           Panama                 1                 1      Costa Rica
# 4          Jamaica                 2                 0          Panama
# 9           Panama                 1                 3          Mexico
# 15     El Salvador                 1                 0          Panama
# 17          Panama                 1                 2   United States
# 21          Canada                 2                 0          Panama
# 25        Honduras                 2                 0          Panama
# 29          Panama                 1                 1     El Salvador
#
#     preds_date
# 1   2021-09-02
# 4   2021-09-05
# 9   2021-09-08
# 15  2021-10-07
# 17  2021-10-10
# 21  2021-10-13
# 25  2021-11-12
# 29  2021-11-16

# %%
# 1 correct home and away score predictions (12.5%)
# 3 correct predictions of outcome (37.5%)
# 4 correct predictions of home team score (50%)
# 2 correct predictions of away team score (25%)
# 1 correct predictions of total goals scored (12.5%)

# %% [markdown]
# ---
