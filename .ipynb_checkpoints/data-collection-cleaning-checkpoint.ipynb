# %% [markdown]
# # Data Collection

# %%
import pandas as pd

# %% [markdown]
# ---

# %% [markdown]
# ### Results DF

# %%
results = pd.read_csv('./data/results.csv')
results.head()
# data from kaggle:  https://www.kaggle.com/martj42/international-football-results-from-1872-to-2017?select=results.csv
# Out:
#          date home_team away_team  home_score  away_score tournament     city  \
# 0  1872-11-30  Scotland   England         0.0         0.0   Friendly  Glasgow
# 1  1873-03-08   England  Scotland         4.0         2.0   Friendly   London
# 2  1874-03-07  Scotland   England         2.0         1.0   Friendly  Glasgow
# 3  1875-03-06   England  Scotland         2.0         2.0   Friendly   London
# 4  1876-03-04  Scotland   England         3.0         0.0   Friendly  Glasgow
#
#     country  neutral
# 0  Scotland    False
# 1   England    False
# 2  Scotland    False
# 3   England    False
# 4  Scotland    False

# %%
results.shape
# Out:
# (43045, 9)

# %%
results[results['date'] < '1992-12-31'].shape  # <- 1st date of FIFA rankings
# Out:
# (17489, 9)

# %%
results.drop(results[results['date'] < '1992-12-31'].index, inplace=True)

# %%
results.shape
# Out:
# (25556, 9)

# %%
results.reset_index(inplace=True)

# %%
results.drop(columns='index', inplace=True)
results.head()
# Out:
#          date     home_team     away_team  home_score  away_score tournament  \
# 0  1993-01-01         Ghana          Mali         1.0         1.0   Friendly
# 1  1993-01-02         Gabon  Burkina Faso         1.0         1.0   Friendly
# 2  1993-01-02        Kuwait       Lebanon         2.0         0.0   Friendly
# 3  1993-01-03  Burkina Faso          Mali         1.0         0.0   Friendly
# 4  1993-01-03         Gabon         Ghana         2.0         3.0   Friendly
#
#           city country  neutral
# 0   Libreville   Gabon     True
# 1   Libreville   Gabon    False
# 2  Kuwait City  Kuwait    False
# 3   Libreville   Gabon     True
# 4   Libreville   Gabon    False

# %% [markdown]
# ---

# %% [markdown]
# ### Upcoming Fixtures DF

# %%
qualifying_fixtures = pd.read_csv('./data/concacaf_wcq_fixtures.csv')
qualifying_fixtures.tail()
# data from FIFA site:  https://www.fifa.com/tournaments/mens/worldcup/qatar2022/qualifiers/concacaf
# Out:
#           date   home_team      away_team  home_score  away_score  \
# 54  2022-03-29      Panama         Canada         NaN         NaN
# 55  2022-03-29  Costa Rica  United States         NaN         NaN
# 56         NaN         NaN            NaN         NaN         NaN
# 57         NaN         NaN            NaN         NaN         NaN
# 58         NaN         NaN            NaN         NaN         NaN
#
#                       tournament city country neutral
# 54  FIFA World Cup qualification  NaN     NaN     NaN
# 55  FIFA World Cup qualification  NaN     NaN     NaN
# 56                           NaN  NaN     NaN     NaN
# 57                           NaN  NaN     NaN     NaN
# 58                           NaN  NaN     NaN     NaN

# %%
qualifying_fixtures[qualifying_fixtures['date'].isnull()]
# Out:
#    date home_team away_team  home_score  away_score tournament city country  \
# 56  NaN       NaN       NaN         NaN         NaN        NaN  NaN     NaN
# 57  NaN       NaN       NaN         NaN         NaN        NaN  NaN     NaN
# 58  NaN       NaN       NaN         NaN         NaN        NaN  NaN     NaN
#
#    neutral
# 56     NaN
# 57     NaN
# 58     NaN

# %%
qualifying_fixtures.drop(index=qualifying_fixtures[qualifying_fixtures['date'].isnull()].index, inplace=True)

# %% [markdown]
# ---

# %% [markdown]
# ### Current Table DF

# %%
table = pd.read_csv('./data/current_table_12.14.2021.csv')
table
# data from FIFA site:  https://www.fifa.com/tournaments/mens/worldcup/qatar2022/qualifiers/concacaf
# Out:
#    rank    team_name  matches_played  wins  draws  losses  goals_for  \
# 0     1       Canada               8     4      4       0         13
# 1     2          USA               8     4      3       1         12
# 2     3       Mexico               8     4      2       2         11
# 3     4       Panama               8     4      2       2         11
# 4     5   Costa Rica               8     2      3       3          6
# 5     6      Jamaica               8     1      4       3          6
# 6     7  El Salvador               8     1      3       4          4
# 7     8     Honduras               8     0      3       5          5
#
#    goals_against  goal_differential  points
# 0              5                  8      16
# 1              5                  7      15
# 2              7                  4      14
# 3              9                  2      14
# 4              7                 -1       9
# 5             10                 -4       7
# 6             10                 -6       6
# 7             15                -10       3

# %% [markdown]
# ---

# %% [markdown]
# ### World Rankings DF

# %%
past_rankings = pd.read_csv('./data/fifa_ranking-2021-05-27.csv')
past_rankings.head()
# data from kaggle:  https://www.kaggle.com/cashncarry/fifaworldranking
# Out:
#         id  rank         country_full country_abrv  total_points  \
# 0    43818    82                 Iraq          IRQ            15
# 1    43873   107           Mozambique          MOZ             9
# 2    43816   108            Indonesia          IDN             9
# 3  1882218   109  Antigua and Barbuda          ATG             8
# 4    43820   110               Jordan          JOR             8
#
#    previous_points  rank_change confederation   rank_date
# 0                0            0           AFC  12/31/1992
# 1                0            0           CAF  12/31/1992
# 2                0            0           AFC  12/31/1992
# 3                0            0      CONCACAF  12/31/1992
# 4                0            0           AFC  12/31/1992

# %%
past_rankings = past_rankings[['rank', 'country_full', 'rank_date']]
past_rankings.head()
# Out:
#    rank         country_full   rank_date
# 0    82                 Iraq  12/31/1992
# 1   107           Mozambique  12/31/1992
# 2   108            Indonesia  12/31/1992
# 3   109  Antigua and Barbuda  12/31/1992
# 4   110               Jordan  12/31/1992

# %%
past_rankings.shape
# Out:
# (63055, 3)

# %%
recent_rankings = pd.read_csv('./data/fifa_ranking_2021-11-19.csv')
recent_rankings.head()
# data from FIFA:  https://www.fifa.com/fifa-world-ranking/
# Out:
#    rank country_full   rank_date
# 0   1.0      Belgium  2021-08-12
# 1   2.0       Brazil  2021-08-12
# 2   3.0       France  2021-08-12
# 3   4.0      England  2021-08-12
# 4   5.0        Italy  2021-08-12

# %%
recent_rankings.shape
# Out:
# (1678, 3)

# %%
rankings = pd.concat([past_rankings, recent_rankings])
rankings.shape
# Out:
# (64733, 3)

# %% [markdown]
# ---

# %% [markdown]
# ### Combining and Cleaning the Data

# %%
rankings.dropna(inplace=True)

# %%
results['home_rank'] = 0

# %%
results['away_rank'] = 0

# %%
results['datetime'] = pd.to_datetime(results['date'])
rankings['datetime'] = pd.to_datetime(rankings['rank_date'])

# %%
results.head()
# Out:
#          date     home_team     away_team  home_score  away_score tournament  \
# 0  1993-01-01         Ghana          Mali         1.0         1.0   Friendly
# 1  1993-01-02         Gabon  Burkina Faso         1.0         1.0   Friendly
# 2  1993-01-02        Kuwait       Lebanon         2.0         0.0   Friendly
# 3  1993-01-03  Burkina Faso          Mali         1.0         0.0   Friendly
# 4  1993-01-03         Gabon         Ghana         2.0         3.0   Friendly
#
#           city country  neutral  home_rank  away_rank   datetime
# 0   Libreville   Gabon     True          0          0 1993-01-01
# 1   Libreville   Gabon    False          0          0 1993-01-02
# 2  Kuwait City  Kuwait    False          0          0 1993-01-02
# 3   Libreville   Gabon     True          0          0 1993-01-03
# 4   Libreville   Gabon    False          0          0 1993-01-03

# %%
results.shape
# Out:
# (25556, 12)

# %%
results.drop(results[(results['home_team'] == 'United Arab Emirates') & (results['datetime'] < '1993-08-08 00:00:00')].index, inplace=True)
# dropping 8 rows of games for UAE because they do not have a rank prior to 1993-08-08 in the dataframe

results.drop(results[(results['home_team'] == 'Netherlands') & (results['datetime'] < '1993-08-08 00:00:00')].index, inplace=True)
# dropping 3 rows of games for Netherlands because they do not have a rank prior to 1993-08-08 in the dataframe

results.drop(results[results['home_team'] == 'Martinique'].index, inplace=True)
# Martinique is not a member of FIFA and therefore will have no rankings

results.drop(results[(results['home_team'] == 'Guyana') & (results['datetime'] < '1993-08-08 00:00:00')].index, inplace=True)
# dropping 3 rows of games for Guyana because they do not have a rank prior to 1993-08-08 in the dataframe

results.drop(results[(results['home_team'] == 'Cayman Islands') & (results['datetime'] < '1993-08-08 00:00:00')].index, inplace=True)
# dropping 1 row of games for Cayman Islands because they do not have a rank prior to 1993-08-08 in the dataframe

results.drop(results[results['home_team'] == 'French Guiana'].index, inplace=True)
# French Guiana is not a member of FIFA and therefore will have no rankings

results.drop(results[(results['home_team'] == 'Slovakia') & (results['datetime'] < '1993-11-19 00:00:00')].index, inplace=True)
# dropping 2 rows of games for Slovakia because they do not have a rank prior to 1993-11-19 in the dataframe

results.drop(results[(results['home_team'] == 'Thailand') & (results['datetime'] < '1993-08-08 00:00:00')].index, inplace=True)
# dropping 5 rows of games for Thailand because they do not have a rank prior to 1993-08-08 in the dataframe

results.drop(results[(results['home_team'] == 'Anguilla') & (results['datetime'] < '1997-05-14 00:00:00')].index, inplace=True)
# dropping 3 rows of games for Angiulla because they do not have a rank prior to 1997-05-14 in the dataframe

results.drop(results[(results['home_team'] == 'Sri Lanka') & (results['datetime'] < '1993-08-08 00:00:00')].index, inplace=True)
# dropping 4 rows of games for Sri Lanka because they do not have a rank prior to 1993-08-08 in the dataframe

results.drop(results[(results['home_team'] == 'Vietnam') & (results['datetime'] < '1993-08-08 00:00:00')].index, inplace=True)
# dropping 4 rows of games for Vietnam because they do not have a rank prior to 1993-08-08 in the dataframe

results.drop(results[results['home_team'] == 'Guadeloupe'].index, inplace=True)
# Guadeloupe is not a member of FIFA and therefore will have no rankings

results.drop(results[(results['home_team'] == 'Latvia') & (results['datetime'] < '1993-08-08 00:00:00')].index, inplace=True)
# dropping 5 rows of games for Latvia because they do not have a rank prior to 1993-08-08 in the dataframe

results.drop(results[(results['home_team'] == 'Dominica') & (results['datetime'] < '1995-02-20 00:00:00')].index, inplace=True)
# dropping 3 rows of games for Dominica because they do not have a rank prior to 1995-02-20 in the dataframe

results.drop(results[(results['home_team'] == 'Czech Republic') & (results['datetime'] < '1994-03-15 00:00:00')].index, inplace=True)
# dropping 3 rows of games for Czech Republic because they do not have a rank prior to 1994-03-15 in the dataframe

results.drop(results[(results['home_team'] == 'Macau') & (results['datetime'] < '1993-08-08 00:00:00')].index, inplace=True)
# dropping 3 rows of games for Macau because they do not have a rank prior to 1993-08-08 in the dataframe

results.drop(results[results['home_team'] == 'Guernsey'].index, inplace=True)
# Guernsey is not a member of FIFA and therefore will have no rankings

results.drop(results[(results['home_team'] == 'Azerbaijan') & (results['datetime'] < '1994-06-14 00:00:00')].index, inplace=True)
# dropping 3 rows of games for Azerbaijan because they do not have a rank prior to 1994-06-14 in the dataframe

results.drop(results[(results['home_team'] == 'Turkmenistan') & (results['datetime'] < '1994-10-25 00:00:00')].index, inplace=True)
# dropping 1 row of games for Turkmenistan because they do not have a rank prior to 1994-10-25 in the dataframe

results.drop(results[(results['home_team'] == 'Bahrain') & (results['datetime'] < '1993-08-08 00:00:00')].index, inplace=True)
# dropping 4 rows of games for Bahrain because they do not have a rank prior to 1993-08-08 in the dataframe

results.drop(results[(results['home_team'] == 'Algeria') & (results['datetime'] < '1993-08-08 00:00:00')].index, inplace=True)
# dropping 4 rows of games for Algeria because they do not have a rank prior to 1993-08-08 in the dataframe

results.drop(results[(results['home_team'] == 'Gibraltar') & (results['datetime'] < '2016-09-15 00:00:00')].index, inplace=True)
# dropping 42 rows of games for Gibraltar because they weren't included in FIFA rankings until 2016-09-15

results.drop(results[results['home_team'] == 'Ynys Môn'].index, inplace=True)
# Ynys Môn is not a member of FIFA and therefore will have no rankings

results.drop(results[results['home_team'] == 'Isle of Wight'].index, inplace=True)
# Isle of Wight is not a member of FIFA and therefore will have no rankings

results.drop(results[results['home_team'] == 'Åland Islands'].index, inplace=True)
# Åland Islands is not a member of FIFA and therefore will have no rankings

results.drop(results[results['home_team'] == 'Jersey'].index, inplace=True)
# Jersey is not a member of FIFA and therefore will have no rankings

results.drop(results[results['home_team'] == 'Isle of Man'].index, inplace=True)
# Isle of Man is not a member of FIFA and therefore will have no rankings

results.drop(results[results['home_team'] == 'Greenland'].index, inplace=True)
# Greenland is not a member of FIFA and therefore will have no rankings

results.drop(results[results['home_team'] == 'Shetland'].index, inplace=True)
# Shetland is not a member of FIFA and therefore will have no rankings

results.drop(results[results['home_team'] == 'Basque Country'].index, inplace=True)
# Basque Country is not a member of FIFA and therefore will have no rankings

results.drop(results[(results['home_team'] == 'Georgia') & (results['datetime'] < '1994-03-15 00:00:00')].index, inplace=True)
# dropping 2 rows of games for Georgia because they do not have a rank prior to 1994-03-15 in the dataframe

results.drop(results[results['home_team'] == 'Sint Maarten'].index, inplace=True)
# Sint Maarten is not a member of FIFA and therefore will have no rankings

results.drop(results[(results['home_team'] == 'North Macedonia') & (results['datetime'] < '1994-05-17 00:00:00')].index, inplace=True)
# dropping 4 rows of games for North Macedonia because they do not have a rank prior to 1994-05-17 in the dataframe

results.drop(results[(results['home_team'] == 'Kazakhstan') & (results['datetime'] < '1994-11-22 00:00:00')].index, inplace=True)
# dropping 2 rows of games for Kazakhstan because they do not have a rank prior to 1994-11-22 in the dataframe

results.drop(results[(results['home_team'] == 'Uzbekistan') & (results['datetime'] < '1994-10-25 00:00:00')].index, inplace=True)
# dropping 4 rows of games for Uzbekistan because they do not have a rank prior to 1994-10-25 in the dataframe

results.drop(results[(results['home_team'] == 'Tajikistan') & (results['datetime'] < '1994-11-22 00:00:00')].index, inplace=True)
# dropping 1 row of games for Tajikistan because they do not have a rank prior to 1994-11-22 in the dataframe

results.drop(results[(results['home_team'] == 'Papua New Guinea') & (results['datetime'] < '1996-09-25 00:00:00')].index, inplace=True)
# dropping 5 rows of games for Papua New Guinea because they do not have a rank prior to 1996-09-25 in the dataframe

results.drop(results[(results['home_team'] == 'Samoa') & (results['datetime'] < '1996-11-20 00:00:00')].index, inplace=True)
# dropping 4 rows of games for Samoa because they do not have a rank prior to 1996-11-20 in the dataframe

results.drop(results[(results['home_team'] == 'Tonga') & (results['datetime'] < '1996-11-20 00:00:00')].index, inplace=True)
# dropping 3 rows of games for Tonga because they do not have a rank prior to 1996-11-20 in the dataframe

results.drop(results[(results['home_team'] == 'Montserrat') & (results['datetime'] < '1999-03-24 00:00:00')].index, inplace=True)
# dropping 1 row of games for Montserrat because they do not have a rank prior to 1999-03-24 in the dataframe

results.drop(results[(results['home_team'] == 'Montenegro') & (results['datetime'] < '2007-06-13 00:00:00')].index, inplace=True)
# dropping 1 row of games for Montenegro because they do not have a rank prior to 2007-06-13 in the dataframe

results.drop(results[(results['home_team'] == 'Serbia and Montenegro') & (results['datetime'] < '2002-12-18 00:00:00')].index, inplace=True)
# dropping 32 rows of games for Serbia and Montenegro because they weren't included in FIFA rankings until 2002-12-18

# %%
# Ensuring country name matches in rankings and results dataframes

rankings.loc[rankings[rankings['country_full'].str.contains('Congo')].index, 'country_full'] = 'Congo'
results.loc[results[results['home_team'].str.contains('Congo')].index, 'home_team'] = 'Congo'

rankings.loc[rankings[rankings['country_full'].str.contains('Swaziland')].index, 'country_full'] = 'Eswatini'
rankings.loc[rankings[rankings['country_full'].str.contains('Eswatini')].index, 'country_full'] = 'Eswatini'
results.loc[results[results['home_team'].str.contains('Eswatini')].index, 'home_team'] = 'Eswatini'

rankings.loc[rankings[rankings['country_full'].str.contains('Korea DPR')].index, 'country_full'] = 'North Korea'
results.loc[results[results['home_team'].str.contains('North Korea')].index, 'home_team'] = 'North Korea'

rankings.loc[rankings[rankings['country_full'].str.contains('USA')].index, 'country_full'] = 'United States'
results.loc[results[results['home_team'].str.contains('USA')].index, 'home_team'] = 'United States'

rankings.loc[rankings[rankings['country_full'].str.contains('Ivoire')].index, 'country_full'] = 'Ivory Coast'
results.loc[results[results['home_team'].str.contains('Ivoire')].index, 'home_team'] = 'Ivory Coast'

rankings.loc[rankings[rankings['country_full'].str.contains('Kitts and Nevis')].index, 'country_full'] = 'St. Kitts and Nevis'
results.loc[results[results['home_team'].str.contains('Kitts and Nevis')].index, 'home_team'] = 'St. Kitts and Nevis'

rankings.loc[rankings[rankings['country_full'].str.contains('Korea Republic')].index, 'country_full'] = 'South Korea'
results.loc[results[results['home_team'].str.contains('Korea Republic')].index, 'home_team'] = 'South Korea'

rankings.loc[rankings[rankings['country_full'].str.contains('St. Vin')].index, 'country_full'] = 'St. Vincent and the Grenadines'
results.loc[results[results['home_team'].str.contains('Vincent')].index, 'home_team'] = 'St. Vincent and the Grenadines'

rankings.loc[rankings[rankings['country_full'].str.contains('Iran')].index, 'country_full'] = 'Iran'
results.loc[results[results['home_team'].str.contains('Iran')].index, 'home_team'] = 'Iran'

rankings.loc[rankings[rankings['country_full'].str.contains('Kyrgyz')].index, 'country_full'] = 'Kyrgyzstan'
results.loc[results[results['home_team'].str.contains('Kyrgyz')].index, 'home_team'] = 'Kyrgyzstan'

results.loc[results[(results['home_team'] == 'Serbia') & (results['datetime'] < '2006-07-12 00:00:00')].index, 'home_team'] = 'Serbia and Montenegro'

# %%
results_dict = results.to_dict('records')
results_dict[0]
# Out:
# {'date': '1993-01-01',
#  'home_team': 'Ghana',
#  'away_team': 'Mali',
#  'home_score': 1.0,
#  'away_score': 1.0,
#  'tournament': 'Friendly',
#  'city': 'Libreville',
#  'country': 'Gabon',
#  'neutral': True,
#  'home_rank': 0,
#  'away_rank': 0,
#  'datetime': Timestamp('1993-01-01 00:00:00')}

# %%
rankings_dict = rankings.to_dict('records')
rankings_dict[0:2]
# Out:
# [{'rank': 82.0,
#   'country_full': 'Iraq',
#   'rank_date': '12/31/1992',
#   'datetime': Timestamp('1992-12-31 00:00:00')},
#  {'rank': 107.0,
#   'country_full': 'Mozambique',
#   'rank_date': '12/31/1992',
#   'datetime': Timestamp('1992-12-31 00:00:00')}]

# %%
# row = results_dict[-1]
def home_rank(row):
    hometeam = row['home_team']
    hometeam

    matchday = row['datetime']
    matchday

    hometeam_rankings = []
    for i in rankings_dict:
        if i['country_full'] == hometeam:
            hometeam_rankings.append(i)

    hometeam_rankings

    previous_rankings = []
    for i in hometeam_rankings:
        if i['datetime'] <= matchday:
            previous_rankings.append(i)
    print(hometeam), print(matchday), print(previous_rankings)
    previous_rankings

    return previous_rankings[-1]['rank']

# %%
results.apply(home_rank, axis=1)
# Out:
# Ghana
# 1993-01-01 00:00:00
# [{'rank': 39.0, 'country_full': 'Ghana', 'rank_date': '12/31/1992', 'datetime': Timestamp('1992-12-31 00:00:00')}]
# Gabon
# 1993-01-02 00:00:00
# [{'rank': 55.0, 'country_full': 'Gabon', 'rank_date': '12/31/1992', 'datetime': Timestamp('1992-12-31 00:00:00')}]
# Kuwait
# 1993-01-02 00:00:00
# [{'rank': 71.0, 'country_full': 'Kuwait', 'rank_date': '12/31/1992', 'datetime': Timestamp('1992-12-31 00:00:00')}]
# Burkina Faso
# 1993-01-03 00:00:00
# [{'rank': 97.0, 'country_full': 'Burkina Faso', 'rank_date': '12/31/1992', 'datetime': Timestamp('1992-12-31 00:00:00')}]
# Gabon
# 1993-01-03 00:00:00
# [{'rank': 55.0, 'country_full': 'Gabon', 'rank_date': '12/31/1992', 'datetime': Timestamp('1992-12-31 00:00:00')}]
# Uganda
# 1993-01-08 00:00:00
# [{'rank': 92.0, 'country_full': 'Uganda', 'rank_date': '12/31/1992', 'datetime': Timestamp('1992-12-31 00:00:00')}]
# Sierra Leone
# 1993-01-09 00:00:00
# [{'rank': 79.0, 'country_full': 'Sierra Leone', 'rank_date': '12/31/1992', 'datetime': Timestamp('1992-12-31 00:00:00')}]
# Angola
# 1993-01-10 00:00:00
# [{'rank': 102.0, 'country_full': 'Angola', 'rank_date': '12/31/1992', 'datetime': Timestamp('1992-12-31 00:00:00')}]
# Botswana
# 1993-01-10 00:00:00
# [{'rank': 139.0, 'country_full': 'Botswana', 'rank_date': '12/31/1992', 'datetime': Timestamp('1992-12-31 00:00:00')}]
# Congo
# 1993-01-10 00:00:00
# [{'rank': 90.0, 'country_full': 'Congo', 'rank_date': '12/31/1992', 'datetime': Timestamp('1992-12-31 00:00:00')}, {'rank': 128.0, 'country_full': 'Congo', 'rank_date': '12/31/1992', 'datetime': Timestamp('1992-12-31 00:00:00')}, {'rank': 29.0, 'country_full': 'Congo', 'rank_date': '12/31/1992', 'datetime': Timestamp('1992-12-31 00:00:00')}]
# Senegal
# 1993-01-10 00:00:00
# [{'rank': 51.0, 'country_full': 'Senegal', 'rank_date': '12/31/1992', 'datetime': Timestamp('1992-12-31 00:00:00')}]
# Tunisia
# 1993-01-10 00:00:00
# [{'rank': 38.0, 'country_full': 'Tunisia', 'rank_date': '12/31/1992', 'datetime': Timestamp('1992-12-31 00:00:00')}]
# Uganda
# 1993-01-10 00:00:00
# [{'rank': 92.0, 'country_full': 'Uganda', 'rank_date': '12/31/1992', 'datetime': Timestamp('1992-12-31 00:00:00')}]
# South Africa
# 1993-01-16 00:00:00
# [{'rank': 124.0, 'country_full': 'South Africa', 'rank_date': '12/31/1992', 'datetime': Timestamp('1992-12-31 00:00:00')}]
# Tanzania
# 1993-01-16 00:00:00
# [{'rank': 80.0, 'country_full': 'Tanzania', 'rank_date': '12/31/1992', 'datetime': Timestamp('1992-12-31 00:00:00')}]
# Benin
# 1993-01-17 00:00:00
# [{'rank': 127.0, 'country_full': 'Benin', 'rank_date': '12/31/1992', 'datetime': Timestamp('1992-12-31 00:00:00')}]
# Botswana
# 1993-01-17 00:00:00
# [{'rank': 139.0, 'country_full': 'Botswana', 'rank_date': '12/31/1992', 'datetime': Timestamp('1992-12-31 00:00:00')}]
# Burundi
# 1993-01-17 00:00:00
# [{'rank': 100.0, 'country_full': 'Burundi', 'rank_date': '12/31/1992', 'datetime': Timestamp('1992-12-31 00:00:00')}]
# Ethiopia
# 1993-01-17 00:00:00
# [{'rank': 85.0, 'country_full': 'Ethiopia', 'rank_date': '12/31/1992', 'datetime': Timestamp('1992-12-31 00:00:00')}]
# Mozambique
# 1993-01-17 00:00:00
# [{'rank': 107.0, 'country_full': 'Mozambique', 'rank_date': '12/31/1992', 'datetime': Timestamp('1992-12-31 00:00:00')}]
# Namibia
# 1993-01-17 00:00:00
# [{'rank': 158.0, 'country_full': 'Namibia', 'rank_date': '12/31/1992', 'datetime': Timestamp('1992-12-31 00:00:00')}]
# Eswatini
# 1993-01-17 00:00:00
# [{'rank': 104.0, 'country_full': 'Eswatini', 'rank_date': '12/31/1992', 'datetime': Timestamp('1992-12-31 00:00:00')}, {'rank': 59.0, 'country_full': 'Eswatini', 'rank_date': '12/31/1992', 'datetime': Timestamp('1992-12-31 00:00:00')}]
# Togo
# 1993-01-17 00:00:00
# [{'rank': 101.0, 'country_full': 'Togo', 'rank_date': '12/31/1992', 'datetime': Timestamp('1992-12-31 00:00:00')}]
# Angola
# 1993-01-18 00:00:00
# [{'rank': 102.0, 'country_full': 'Angola', 'rank_date': '12/31/1992', 'datetime': Timestamp('1992-12-31 00:00:00')}]
# North Korea
# 1993-01-19 00:00:00
# [{'rank': 7.0, 'country_full': 'North Korea', 'rank_date': '12/31/1992', 'datetime': Timestamp('1992-12-31 00:00:00')}, {'rank': 77.0, 'country_full': 'North Korea', 'rank_date': '12/31/1992', 'datetime': Timestamp('1992-12-31 00:00:00')}]
# Guinea-Bissau
# 1993-01-20 00:00:00
# [{'rank': 117.0, 'country_full': 'Guinea-Bissau', 'rank_date': '12/31/1992', 'datetime': Timestamp('1992-12-31 00:00:00')}]
# India
# 1993-01-20 00:00:00
# [{'rank': 143.0, 'country_full': 'India', 'rank_date': '12/31/1992', 'datetime': Timestamp('1992-12-31 00:00:00')}]
# Italy
# 1993-01-20 00:00:00
# [{'rank': 2.0, 'country_full': 'Italy', 'rank_date': '12/31/1992', 'datetime': Timestamp('1992-12-31 00:00:00')}]
# Cameroon
# 1993-01-22 00:00:00
# [{'rank': 22.0, 'country_full': 'Cameroon', 'rank_date': '12/31/1992', 'datetime': Timestamp('1992-12-31 00:00:00')}]
# Ghana
# 1993-01-23 00:00:00
# [{'rank': 39.0, 'country_full': 'Ghana', 'rank_date': '12/31/1992', 'datetime': Timestamp('1992-12-31 00:00:00')}]
# Guinea-Bissau
# 1993-01-23 00:00:00
# [{'rank': 117.0, 'country_full': 'Guinea-Bissau', 'rank_date': '12/31/1992', 'datetime': Timestamp('1992-12-31 00:00:00')}]
# Venezuela
# 1993-01-23 00:00:00
# [{'rank': 125.0, 'country_full': 'Venezuela', 'rank_date': '12/31/1992', 'datetime': Timestamp('1992-12-31 00:00:00')}]
# India
# 1993-01-24 00:00:00
# [{'rank': 143.0, 'country_full': 'India', 'rank_date': '12/31/1992', 'datetime': Timestamp('1992-12-31 00:00:00')}]
# Malta
# 1993-01-24 00:00:00
# [{'rank': 73.0, 'country_full': 'Malta', 'rank_date': '12/31/1992', 'datetime': Timestamp('1992-12-31 00:00:00')}]
# Togo
# 1993-01-24 00:00:00
# [{'rank': 101.0, 'country_full': 'Togo', 'rank_date': '12/31/1992', 'datetime': Timestamp('1992-12-31 00:00:00')}]
# Bolivia
# 1993-01-25 00:00:00
# [{'rank': 87.0, 'country_full': 'Bolivia', 'rank_date': '12/31/1992', 'datetime': Timestamp('1992-12-31 00:00:00')}]
# India
# 1993-01-26 00:00:00
# [{'rank': 143.0, 'country_full': 'India', 'rank_date': '12/31/1992', 'datetime': Timestamp('1992-12-31 00:00:00')}]
# Ecuador
# 1993-01-27 00:00:00
# [{'rank': 65.0, 'country_full': 'Ecuador', 'rank_date': '12/31/1992', 'datetime': Timestamp('1992-12-31 00:00:00')}]
# Peru
# 1993-01-27 00:00:00
# [{'rank': 78.0, 'country_full': 'Peru', 'rank_date': '12/31/1992', 'datetime': Timestamp('1992-12-31 00:00:00')}]
# Spain
# 1993-01-27 00:00:00
# [{'rank': 15.0, 'country_full': 'Spain', 'rank_date': '12/31/1992', 'datetime': Timestamp('1992-12-31 00:00:00')}]
# Cameroon
# 1993-01-28 00:00:00
# [{'rank': 22.0, 'country_full': 'Cameroon', 'rank_date': '12/31/1992', 'datetime': Timestamp('1992-12-31 00:00:00')}]
# Bolivia
# 1993-01-29 00:00:00
# [{'rank': 87.0, 'country_full': 'Bolivia', 'rank_date': '12/31/1992', 'datetime': Timestamp('1992-12-31 00:00:00')}]
# India
# 1993-01-30 00:00:00
# [{'rank': 143.0, 'country_full': 'India', 'rank_date': '12/31/1992', 'datetime': Timestamp('1992-12-31 00:00:00')}]
# Peru
# 1993-01-30 00:00:00
# [{'rank': 78.0, 'country_full': 'Peru', 'rank_date': '12/31/1992', 'datetime': Timestamp('1992-12-31 00:00:00')}]
# Senegal
# 1993-01-30 00:00:00
# [{'rank': 51.0, 'country_full': 'Senegal', 'rank_date': '12/31/1992', 'datetime': Timestamp('1992-12-31 00:00:00')}]
# United States
# 1993-01-30 00:00:00
# [{'rank': 106.0, 'country_full': 'United States', 'rank_date': '12/31/1992', 'datetime': Timestamp('1992-12-31 00:00:00')}, {'rank': 24.0, 'country_full': 'United States', 'rank_date': '12/31/1992', 'datetime': Timestamp('1992-12-31 00:00:00')}]
# Zambia
# 1993-01-30 00:00:00
# [{'rank': 32.0, 'country_full': 'Zambia', 'rank_date': '12/31/1992', 'datetime': Timestamp('1992-12-31 00:00:00')}]
# Congo
# 1993-01-31 00:00:00
# [{'rank': 90.0, 'country_full': 'Congo', 'rank_date': '12/31/1992', 'datetime': Timestamp('1992-12-31 00:00:00')}, {'rank': 128.0, 'country_full': 'Congo', 'rank_date': '12/31/1992', 'datetime': Timestamp('1992-12-31 00:00:00')}, {'rank': 29.0, 'country_full': 'Congo', 'rank_date': '12/31/1992', 'datetime': Timestamp('1992-12-31 00:00:00')}]
# Ecuador
# 1993-01-31 00:00:00
# [{'rank': 65.0, 'country_full': 'Ecuador', 'rank_date': '12/31/1992', 'datetime': Timestamp('1992-12-31 00:00:00')}]
# Egypt
# 1993-01-31 00:00:00
# [{'rank': 21.0, 'country_full': 'Egypt', 'rank_date': '12/31/1992', 'datetime': Timestamp('1992-12-31 00:00:00')}]
# Ghana
# 1993-01-31 00:00:00
# [{'rank': 39.0, 'country_full': 'Ghana', 'rank_date': '12/31/1992', 'datetime': Timestamp('1992-12-31 00:00:00')}]
# Ivory Coast
# 1993-01-31 00:00:00
# [{'rank': 162.0, 'country_full': 'Ivory Coast', 'rank_date': '12/31/1992', 'datetime': Timestamp('1992-12-31 00:00:00')}, {'rank': 27.0, 'country_full': 'Ivory Coast', 'rank_date': '12/31/1992', 'datetime': Timestamp('1992-12-31 00:00:00')}]
# North Korea
# 1993-01-31 00:00:00
# [{'rank': 7.0, 'country_full': 'North Korea', 'rank_date': '12/31/1992', 'datetime': Timestamp('1992-12-31 00:00:00')}, {'rank': 77.0, 'country_full': 'North Korea', 'rank_date': '12/31/1992', 'datetime': Timestamp('1992-12-31 00:00:00')}]
# Morocco
# 1993-01-31 00:00:00
# [{'rank': 41.0, 'country_full': 'Morocco', 'rank_date': '12/31/1992', 'datetime': Timestamp('1992-12-31 00:00:00')}]
# Tunisia
# 1993-01-31 00:00:00
# [{'rank': 38.0, 'country_full': 'Tunisia', 'rank_date': '12/31/1992', 'datetime': Timestamp('1992-12-31 00:00:00')}]
# Zimbabwe
# 1993-01-31 00:00:00
# [{'rank': 54.0, 'country_full': 'Zimbabwe', 'rank_date': '12/31/1992', 'datetime': Timestamp('1992-12-31 00:00:00')}]
# Cyprus
# 1993-02-01 00:00:00
# [{'rank': 72.0, 'country_full': 'Cyprus', 'rank_date': '12/31/1992', 'datetime': Timestamp('1992-12-31 00:00:00')}]
# Israel
# 1993-02-03 00:00:00
# [{'rank': 64.0, 'country_full': 'Israel', 'rank_date': '12/31/1992', 'datetime': Timestamp('1992-12-31 00:00:00')}]
# Peru
# 1993-02-03 00:00:00
# [{'rank': 78.0, 'country_full': 'Peru', 'rank_date': '12/31/1992', 'datetime': Timestamp('1992-12-31 00:00:00')}]
# Malaysia
# 1993-02-05 00:00:00
# [{'rank': 91.0, 'country_full': 'Malaysia', 'rank_date': '12/31/1992', 'datetime': Timestamp('1992-12-31 00:00:00')}]
# Ghana
# 1993-02-06 00:00:00
# [{'rank': 39.0, 'country_full': 'Ghana', 'rank_date': '12/31/1992', 'datetime': Timestamp('1992-12-31 00:00:00')}]
# United States
# 1993-02-06 00:00:00
# [{'rank': 106.0, 'country_full': 'United States', 'rank_date': '12/31/1992', 'datetime': Timestamp('1992-12-31 00:00:00')}, {'rank': 24.0, 'country_full': 'United States', 'rank_date': '12/31/1992', 'datetime': Timestamp('1992-12-31 00:00:00')}]
# Malaysia
# 1993-02-07 00:00:00
# [{'rank': 91.0, 'country_full': 'Malaysia', 'rank_date': '12/31/1992', 'datetime': Timestamp('1992-12-31 00:00:00')}]
# Singapore
# 1993-02-09 00:00:00
# [{'rank': 89.0, 'country_full': 'Singapore', 'rank_date': '12/31/1992', 'datetime': Timestamp('1992-12-31 00:00:00')}]
# Mexico
# 1993-02-10 00:00:00
# [{'rank': 25.0, 'country_full': 'Mexico', 'rank_date': '12/31/1992', 'datetime': Timestamp('1992-12-31 00:00:00')}]
# Portugal
# 1993-02-10 00:00:00
# [{'rank': 33.0, 'country_full': 'Portugal', 'rank_date': '12/31/1992', 'datetime': Timestamp('1992-12-31 00:00:00')}]
# Cyprus
# 1993-02-13 00:00:00
# [{'rank': 72.0, 'country_full': 'Cyprus', 'rank_date': '12/31/1992', 'datetime': Timestamp('1992-12-31 00:00:00')}]
# United States
# 1993-02-13 00:00:00
# [{'rank': 106.0, 'country_full': 'United States', 'rank_date': '12/31/1992', 'datetime': Timestamp('1992-12-31 00:00:00')}, {'rank': 24.0, 'country_full': 'United States', 'rank_date': '12/31/1992', 'datetime': Timestamp('1992-12-31 00:00:00')}]
# Costa Rica
# 1993-02-16 00:00:00
# [{'rank': 37.0, 'country_full': 'Costa Rica', 'rank_date': '12/31/1992', 'datetime': Timestamp('1992-12-31 00:00:00')}]
# Albania
# 1993-02-17 00:00:00
# [{'rank': 86.0, 'country_full': 'Albania', 'rank_date': '12/31/1992', 'datetime': Timestamp('1992-12-31 00:00:00')}]
# El Salvador
# 1993-02-17 00:00:00
# [{'rank': 50.0, 'country_full': 'El Salvador', 'rank_date': '12/31/1992', 'datetime': Timestamp('1992-12-31 00:00:00')}]
# England
# 1993-02-17 00:00:00
# [{'rank': 5.0, 'country_full': 'England', 'rank_date': '12/31/1992', 'datetime': Timestamp('1992-12-31 00:00:00')}]
# Greece
# 1993-02-17 00:00:00
# [{'rank': 31.0, 'country_full': 'Greece', 'rank_date': '12/31/1992', 'datetime': Timestamp('1992-12-31 00:00:00')}, {'rank': 31.0, 'country_full': 'Greece', 'rank_date': '12/31/1992', 'datetime': Timestamp('1992-12-31 00:00:00')}]
# Republic of Ireland
# 1993-02-17 00:00:00
# [{'rank': 6.0, 'country_full': 'Republic of Ireland', 'rank_date': '12/31/1992', 'datetime': Timestamp('1992-12-31 00:00:00')}]
# Israel
# 1993-02-17 00:00:00
# [{'rank': 64.0, 'country_full': 'Israel', 'rank_date': '12/31/1992', 'datetime': Timestamp('1992-12-31 00:00:00')}]
# Scotland
# 1993-02-17 00:00:00
# [{'rank': 23.0, 'country_full': 'Scotland', 'rank_date': '12/31/1992', 'datetime': Timestamp('1992-12-31 00:00:00')}]
# Argentina
# 1993-02-18 00:00:00
# [{'rank': 10.0, 'country_full': 'Argentina', 'rank_date': '12/31/1992', 'datetime': Timestamp('1992-12-31 00:00:00')}]
# Costa Rica
# 1993-02-19 00:00:00
# [{'rank': 37.0, 'country_full': 'Costa Rica', 'rank_date': '12/31/1992', 'datetime': Timestamp('1992-12-31 00:00:00')}]
# Finland
# 1993-02-20 00:00:00
# [{'rank': 44.0, 'country_full': 'Finland', 'rank_date': '12/31/1992', 'datetime': Timestamp('1992-12-31 00:00:00')}]
#
', 'rank_date': '12/31/1992', 'datetime': Timestamp('1992-12-31 00:00:00')}]
# Bangladesh
# 1993-04-30 00:00:00
# [{'rank': 133.0, 'country_full': 'Bangladesh', 'rank_date': '12/31/1992', 'datetime': Timestamp('1992-12-31 00:00:00')}]
# Indonesia
# 1993-04-30 00:00:00
# [{'rank': 108.0, 'country_full': 'Indonesia', 'rank_date': '12/31/1992', 'datetime': Timestamp('1992-12-31 00:00:00')}]
# Singapore
# 1993-04-30 00:00:00
# [{'rank': 89.0, 'country_full': 'Singapore', 'rank_date': '12/31/1992', 'datetime': Timestamp('1992-12-31 00:00:00')}]
# Malaysia
# 1993-05-01 00:00:00
# [{'rank': 91.0, 'country_full': 'Malaysia', 'rank_date': '12/31/1992', 'datetime': Timestamp('1992-12-31 00:00:00')}]
# Switzerland
# 1993-05-01 00:00:00
# [{'rank': 12.0, 'country_full': 'Switzerland', 'rank_date': '12/31/1992', 'datetime': Timestamp('1992-12-31 00:00:00')}]
# El Salvador
# 1993-05-02 00:00:00
# [{'rank': 50.0, 'country_full': 'El Salvador', 'rank_date': '12/31/1992', 'datetime': Timestamp('1992-12-31 00:00:00')}]
# Guinea
# 1993-05-02 00:00:00
# [{'rank': 63.0, 'country_full': 'Guinea', 'rank_date': '12/31/1992', 'datetime': Timestamp('1992-12-31 00:00:00')}]
# Honduras
# 1993-05-02 00:00:00
# [{'rank': 40.0, 'country_full': 'Honduras', 'rank_date': '12/31/1992', 'datetime': Timestamp('1992-12-31 00:00:00')}]
# Ivory Coast
# 1993-05-02 00:00:00
# [{'rank': 162.0, 'country_full': 'Ivory Coast', 'rank_date': '12/31/1992', 'datetime': Timestamp('1992-12-31 00:00:00')}, {'rank': 27.0, 'country_full': 'Ivory Coast', 'rank_date': '12/31/1992', 'datetime': Timestamp('1992-12-31 00:00:00')}]
# North Korea
# 1993-05-02 00:00:00
# [{'rank': 7.0, 'country_full': 'North Korea', 'rank_date': '12/31/1992', 'datetime': Timestamp('1992-12-31 00:00:00')}, {'rank': 77.0, 'country_full': 'North Korea', 'rank_date': '12/31/1992', 'datetime': Timestamp('1992-12-31 00:00:00')}]
# Singapore
# 1993-05-02 00:00:00
# [{'rank': 89.0, 'country_full': 'Singapore', 'rank_date': '12/31/1992', 'datetime': Timestamp('1992-12-31 00:00:00')}]
# Malaysia
# 1993-05-03 00:00:00
# [{'rank': 91.0, 'country_full': 'Malaysia', 'rank_date': '12/31/1992', 'datetime': Timestamp('1992-12-31 00:00:00')}]
# Bangladesh
# 1993-05-05 00:00:00
# [{'rank': 133.0, 'country_full': 'Bangladesh', 'rank_date': '12/31/1992', 'datetime': Timestamp('1992-12-31 00:00:00')}]
# Kuwait
# 1993-05-05 00:00:00
# [{'rank': 71.0, 'country_full': 'Kuwait', 'rank_date': '12/31/1992', 'datetime': Timestamp('1992-12-31 00:00:00')}]
# Malaysia
# 1993-05-05 00:00:00
# [{'rank': 91.0, 'country_full': 'Malaysia', 'rank_date': '12/31/1992', 'datetime': Timestamp('1992-12-31 00:00:00')}]
# Bangladesh
# 1993-05-07 00:00:00
# [{'rank': 133.0, 'country_full': 'Bangladesh', 'rank_date': '12/31/1992', 'datetime': Timestamp('1992-12-31 00:00:00')}]
# Hong Kong
# 1993-05-07 00:00:00
# [{'rank': 119.0, 'country_full': 'Hong Kong', 'rank_date': '12/31/1992', 'datetime': Timestamp('1992-12-31 00:00:00')}]
# Lebanon
# 1993-05-07 00:00:00
# [{'rank': 161.0, 'country_full': 'Lebanon', 'rank_date': '12/31/1992', 'datetime': Timestamp('1992-12-31 00:00:00')}]
# United States
# 1993-05-08 00:00:00
# [{'rank': 106.0, 'country_full': 'United States', 'rank_date': '12/31/1992', 'datetime': Timestamp('1992-12-31 00:00:00')}, {'rank': 24.0, 'country_full': 'United States', 'rank_date': '12/31/1992', 'datetime': Timestamp('1992-12-31 00:00:00')}]
# Canada
# 1993-05-09 00:00:00
# [{'rank': 57.0, 'country_full': 'Canada', 'rank_date': '12/31/1992', 'datetime': Timestamp('1992-12-31 00:00:00')}]
# El Salvador
# 1993-05-09 00:00:00
# [{'rank': 50.0, 'country_full': 'El Salvador', 'rank_date': '12/31/1992', 'datetime': Timestamp('1992-12-31 00:00:00')}]
# Lebanon
# 1993-05-09 00:00:00
# [{'rank': 161.0, 'country_full': 'Lebanon', 'rank_date': '12/31/1992', 'datetime': Timestamp('1992-12-31 00:00:00')}]
# India
# 1993-05-11 00:00:00
# [{'rank': 143.0, 'country_full': 'India', 'rank_date': '12/31/1992', 'datetime': Timestamp('1992-12-31 00:00:00')}]
# Lebanon
# 1993-05-11 00:00:00
# [{'rank': 161.0, 'country_full': 'Lebanon', 'rank_date': '12/31/1992', 'datetime': Timestamp('1992-12-31 00:00:00')}]
# Bulgaria
# 1993-05-12 00:00:00
# [{'rank': 26.0, 'country_full': 'Bulgaria', 'rank_date': '12/31/1992', 'datetime': Timestamp('1992-12-31 00:00:00')}]
# Estonia
# 1993-05-12 00:00:00
# [{'rank': 132.0, 'country_full': 'Estonia', 'rank_date': '12/31/1992', 'datetime': Timestamp('1992-12-31 00:00:00')}]
# Finland
# 1993-05-13 00:00:00
# [{'rank': 44.0, 'country_full': 'Finland', 'rank_date': '12/31/1992', 'datetime': Timestamp('1992-12-31 00:00:00')}]
# India
# 1993-05-13 00:00:00
# [{'rank': 143.0, 'country_full': 'India', 'rank_date': '12/31/1992', 'datetime': Timestamp('1992-12-31 00:00:00')}]
# Lebanon
# 1993-05-13 00:00:00
# [{'rank': 161.0, 'country_full': 'Lebanon', 'rank_date': '12/31/1992', 'datetime': Timestamp('1992-12-31 00:00:00')}]
# Kuwait
# 1993-05-14 00:00:00
# [{'rank': 71.0, 'country_full': 'Kuwait', 'rank_date': '12/31/1992', 'datetime': Timestamp('1992-12-31 00:00:00')}]
# Saudi Arabia
# 1993-05-14 00:00:00
# [{'rank': 48.0, 'country_full': 'Saudi Arabia', 'rank_date': '12/31/1992', 'datetime': Timestamp('1992-12-31 00:00:00')}]
# Hong Kong
# 1993-05-15 00:00:00
# [{'rank': 119.0, 'country_full': 'Hong Kong', 'rank_date': '12/31/1992', 'datetime': Timestamp('1992-12-31 00:00:00')}]
# Kuwait
# 1993-05-16 00:00:00
# [{'rank': 71.0, 'country_full': 'Kuwait', 'rank_date': '12/31/1992', 'datetime': Timestamp('1992-12-31 00:00:00')}]
# Saudi Arabia
# 1993-05-16 00:00:00
# [{'rank': 48.0, 'country_full': 'Saudi Arabia', 'rank_date': '12/31/1992', 'datetime': Timestamp('1992-12-31 00:00:00')}]
# Lithuania
# 1993-05-18 00:00:00
# [{'rank': 93.0, 'country_full': 'Lithuania', 'rank_date': '12/31/1992', 'datetime': Timestamp('1992-12-31 00:00:00')}]
# Saudi Arabia
# 1993-05-18 00:00:00
# [{'rank': 48.0, 'country_full': 'Saudi Arabia', 'rank_date': '12/31/1992', 'datetime': Timestamp('1992-12-31 00:00:00')}]
# Estonia
# 1993-05-19 00:00:00
# [{'rank': 132.0, 'country_full': 'Estonia', 'rank_date': '12/31/1992', 'datetime': Timestamp('1992-12-31 00:00:00')}]
# San Marino
# 1993-05-19 00:00:00
# [{'rank': 126.0, 'country_full': 'San Marino', 'rank_date': '12/31/1992', 'datetime': Timestamp('1992-12-31 00:00:00')}]
# Sweden
# 1993-05-19 00:00:00
# [{'rank': 4.0, 'country_full': 'Sweden', 'rank_date': '12/31/1992', 'datetime': Timestamp('1992-12-31 00:00:00')}]
# Luxembourg
# 1993-05-20 00:00:00
# [{'rank': 103.0, 'country_full': 'Luxembourg', 'rank_date': '12/31/1992', 'datetime': Timestamp('1992-12-31 00:00:00')}]
# Zambia
# 1993-05-20 00:00:00
# [{'rank': 32.0, 'country_full': 'Zambia', 'rank_date': '12/31/1992', 'datetime': Timestamp('1992-12-31 00:00:00')}]
# Colombia
# 1993-05-21 00:00:00
# [{'rank': 35.0, 'country_full': 'Colombia', 'rank_date': '12/31/1992', 'datetime': Timestamp('1992-12-31 00:00:00')}]
# Jamaica
# 1993-05-21 00:00:00
# [{'rank': 67.0, 'country_full': 'Jamaica', 'rank_date': '12/31/1992', 'datetime': Timestamp('1992-12-31 00:00:00')}]
# Puerto Rico
# 1993-05-21 00:00:00
# [{'rank': 122.0, 'country_full': 'Puerto Rico', 'rank_date': '12/31/1992', 'datetime': Timestamp('1992-12-31 00:00:00')}]
# Belgium
# 1993-05-22 00:00:00
# [{'rank': 17.0, 'country_full': 'Belgium', 'rank_date': '12/31/1992', 'datetime': Timestamp('1992-12-31 00:00:00')}]
# Burkina Faso
# 1993-05-22 00:00:00
# [{'rank': 97.0, 'country_full': 'Burkina Faso', 'rank_date': '12/31/1992', 'datetime': Timestamp('1992-12-31 00:00:00')}]
# Jordan
# 1993-05-22 00:00:00
# [{'rank': 110.0, 'country_full': 'Jordan', 'rank_date': '12/31/1992', 'datetime': Timestamp('1992-12-31 00:00:00')}]
# New Zealand
# 1993-05-22 00:00:00
# [{'rank': 70.0, 'country_full': 'New Zealand', 'rank_date': '12/31/1992', 'datetime': Timestamp('1992-12-31 00:00:00')}]
# Pakistan
# 1993-05-22 00:00:00
# [{'rank': 145.0, 'country_full': 'Pakistan', 'rank_date': '12/31/1992', 'datetime': Timestamp('1992-12-31 00:00:00')}]
# Zambia
# 1993-05-22 00:00:00
# [{'rank': 32.0, 'country_full': 'Zambia', 'rank_date': '12/31/1992', 'datetime': Timestamp('1992-12-31 00:00:00')}]
# Jamaica
# 1993-05-23 00:00:00
# [{'rank': 67.0, 'country_full': 'Jamaica', 'rank_date': '12/31/1992', 'datetime': Timestamp('1992-12-31 00:00:00')}]
# Russia
# 1993-05-23 00:00:00
# [{'rank': 8.0, 'country_full': 'Russia', 'rank_date': '12/31/1992', 'datetime': Timestamp('1992-12-31 00:00:00')}]
# St. Kitts and Nevis
# 1993-05-23 00:00:00
# [{'rank': 75.0, 'country_full': 'St. Kitts and Nevis', 'rank_date': '12/31/1992', 'datetime': Timestamp('1992-12-31 00:00:00')}]
# Trinidad and Tobago
# 1993-05-23 00:00:00
# [{'rank': 62.0, 'country_full': 'Trinidad and Tobago', 'rank_date': '12/31/1992', 'datetime': Timestamp('1992-12-31 00:00:00')}]
# United States
# 1993-05-23 00:00:00
# [{'rank': 106.0, 'country_full': 'United States', 'rank_date': '12/31/1992', 'datetime': Timestamp('1992-12-31 00:00:00')}, {'rank': 24.0, 'country_full': 'United States', 'rank_date': '12/31/1992', 'datetime': Timestamp('1992-12-31 00:00:00')}]
# Jordan
# 1993-05-24 00:00:00
# [{'rank': 110.0, 'country_full': 'Jordan', 'rank_date': '12/31/1992', 'datetime': Timestamp('1992-12-31 00:00:00')}]
# New Zealand
# 1993-05-24 00:00:00
# [{'rank': 70.0, 'country_full': 'New Zealand', 'rank_date': '12/31/1992', 'datetime': Timestamp('1992-12-31 00:00:00')}]
# Yemen
# 1993-05-24 00:00:00
# [{'rank': 115.0, 'country_full': 'Yemen', 'rank_date': '12/31/1992', 'datetime': Timestamp('1992-12-31 00:00:00')}]
# Zambia
# 1993-05-24 00:00:00
# [{'rank': 32.0, 'country_full': 'Zambia', 'rank_date': '12/31/1992', 'datetime': Timestamp('1992-12-31 00:00:00')}]
# Jamaica
# 1993-05-25 00:00:00
# [{'rank': 67.0, 'country_full': 'Jamaica', 'rank_date': '12/31/1992', 'datetime': Timestamp('1992-12-31 00:00:00')}]
# Lithuania
# 1993-05-25 00:00:00
# [{'rank': 93.0, 'country_full': 'Lithuania', 'rank_date': '12/31/1992', 'datetime': Timestamp('1992-12-31 00:00:00')}]
# St. Kitts and Nevis
# 1993-05-25 00:00:00
# [{'rank': 75.0, 'country_full': 'St. Kitts and Nevis', 'rank_date': '12/31/1992', 'datetime': Timestamp('1992-12-31 00:00:00')}]
# St. Vincent and the Grenadines
# 1993-05-25 00:00:00
# [{'rank': 105.0, 'country_full': 'St. Vincent and the Grenadines', 'rank_date': '12/31/1992', 'datetime': Timestamp('1992-12-31 00:00:00')}]
# Albania
# 1993-05-26 00:00:00
# [{'rank': 86.0, 'country_full': 'Albania', 'rank_date': '12/31/1992', 'datetime': Timestamp('1992-12-31 00:00:00')}]
# Ethiopia
# 1993-05-26 00:00:00
# [{'rank': 85.0, 'country_full': 'Ethiopia', 'rank_date': '12/31/1992', 'datetime': Timestamp('1992-12-31 00:00:00')}]
# Jordan
# 1993-05-26 00:00:00
# [{'rank': 110.0, 'country_full': 'Jordan', 'rank_date': '12/31/1992', 'datetime': Timestamp('1992-12-31 00:00:00')}]
# United States
# 1993-05-26 00:00:00
# [{'rank': 106.0, 'country_full': 'United States', 'rank_date': '12/31/1992', 'datetime': Timestamp('1992-12-31 00:00:00')}, {'rank': 24.0, 'country_full': 'United States', 'rank_date': '12/31/1992', 'datetime': Timestamp('1992-12-31 00:00:00')}]
# Yemen
# 1993-05-26 00:00:00
# [{'rank': 115.0, 'country_full': 'Yemen', 'rank_date': '12/31/1992', 'datetime': Timestamp('1992-12-31 00:00:00')}]
# Bolivia
# 1993-05-27 00:00:00
# [{'rank': 87.0, 'country_full': 'Bolivia', 'rank_date': '12/31/1992', 'datetime': Timestamp('1992-12-31 00:00:00')}]
# Jamaica
# 1993-05-28 00:00:00
# [{'rank': 67.0, 'country_full': 'Jamaica', 'rank_date': '12/31/1992', 'datetime': Timestamp('1992-12-31 00:00:00')}]
# Pakistan
# 1993-05-28 00:00:00
# [{'rank': 145.0, 'country_full': 'Pakistan', 'rank_date': '12/31/1992', 'datetime': Timestamp('1992-12-31 00:00:00')}]
# Yemen
# 1993-05-28 00:00:00
# [{'rank': 115.0, 'country_full': 'Yemen', 'rank_date': '12/31/1992', 'datetime': Timestamp('1992-12-31 00:00:00')}]
# Republic of Ireland
# 1993-05-29 00:00:00
# [{'rank': 6.0, 'country_full': 'Republic of Ireland', 'rank_date': '12/31/1992', 'datetime': Timestamp('1992-12-31 00:00:00')}]
# Poland
# 1993-05-29 00:00:00
# [{'rank': 20.0, 'country_full': 'Poland', 'rank_date': '12/31/1992', 'datetime': Timestamp('1992-12-31 00:00:00')}]
# Chile
# 1993-05-30 00:00:00
# ...
# Zambia
# 1995-04-08 00:00:00
# [{'rank': 32.0, 'country_full': 'Zambia', 'rank_date': '12/31/1992', 'datetime': Timestamp('1992-12-31 00:00:00')}, {'rank': 25.0, 'country_full': 'Zambia', 'rank_date': '8/8/1993', 'datetime': Timestamp('1993-08-08 00:00:00')}, {'rank': 27.0, 'country_full': 'Zambia', 'rank_date': '9/23/1993', 'datetime': Timestamp('1993-09-23 00:00:00')}, {'rank': 25.0, 'country_full': 'Zambia', 'rank_date': '10/22/1993', 'datetime': Timestamp('1993-10-22 00:00:00')}, {'rank': 29.0, 'country_full': 'Zambia', 'rank_date': '11/19/1993', 'datetime': Timestamp('1993-11-19 00:00:00')}, {'rank': 27.0, 'country_full': 'Zambia', 'rank_date': '12/23/1993', 'datetime': Timestamp('1993-12-23 00:00:00')}, {'rank': 30.0, 'country_full': 'Zambia', 'rank_date': '2/15/1994', 'datetime': Timestamp('1994-02-15 00:00:00')}, {'rank': 22.0, 'country_full': 'Zambia', 'rank_date': '3/15/1994', 'datetime': Timestamp('1994-03-15 00:00:00')}, {'rank': 19.0, 'country_full': 'Zambia', 'rank_date': '4/19/1994', 'datetime': Timestamp('1994-04-19 00:00:00')}, {'rank': 19.0, 'country_full': 'Zambia', 'rank_date': '5/17/1994', 'datetime': Timestamp('1994-05-17 00:00:00')}, {'rank': 20.0, 'country_full': 'Zambia', 'rank_date': '6/14/1994', 'datetime': Timestamp('1994-06-14 00:00:00')}, {'rank': 21.0, 'country_full': 'Zambia', 'rank_date': '7/21/1994', 'datetime': Timestamp('1994-07-21 00:00:00')}, {'rank': 21.0, 'country_full': 'Zambia', 'rank_date': '9/13/1994', 'datetime': Timestamp('1994-09-13 00:00:00')}, {'rank': 20.0, 'country_full': 'Zambia', 'rank_date': '10/25/1994', 'datetime': Timestamp('1994-10-25 00:00:00')}, {'rank': 20.0, 'country_full': 'Zambia', 'rank_date': '11/22/1994', 'datetime': Timestamp('1994-11-22 00:00:00')}, {'rank': 21.0, 'country_full': 'Zambia', 'rank_date': '12/20/1994', 'datetime': Timestamp('1994-12-20 00:00:00')}, {'rank': 21.0, 'country_full': 'Zambia', 'rank_date': '2/20/1995', 'datetime': Timestamp('1995-02-20 00:00:00')}]
# Gambia
# 1995-04-09 00:00:00
# [{'rank': 150.0, 'country_full': 'Gambia', 'rank_date': '12/31/1992', 'datetime': Timestamp('1992-12-31 00:00:00')}, {'rank': 154.0, 'country_full': 'Gambia', 'rank_date': '8/8/1993', 'datetime': Timestamp('1993-08-08 00:00:00')}, {'rank': 152.0, 'country_full': 'Gambia', 'rank_date': '9/23/1993', 'datetime': Timestamp('1993-09-23 00:00:00')}, {'rank': 152.0, 'country_full': 'Gambia', 'rank_date': '10/22/1993', 'datetime': Timestamp('1993-10-22 00:00:00')}, {'rank': 153.0, 'country_full': 'Gambia', 'rank_date': '11/19/1993', 'datetime': Timestamp('1993-11-19 00:00:00')}, {'rank': 125.0, 'country_full': 'Gambia', 'rank_date': '12/23/1993', 'datetime': Timestamp('1993-12-23 00:00:00')}, {'rank': 125.0, 'country_full': 'Gambia', 'rank_date': '2/15/1994', 'datetime': Timestamp('1994-02-15 00:00:00')}, {'rank': 110.0, 'country_full': 'Gambia', 'rank_date': '3/15/1994', 'datetime': Timestamp('1994-03-15 00:00:00')}, {'rank': 109.0, 'country_full': 'Gambia', 'rank_date': '4/19/1994', 'datetime': Timestamp('1994-04-19 00:00:00')}, {'rank': 108.0, 'country_full': 'Gambia', 'rank_date': '5/17/1994', 'datetime': Timestamp('1994-05-17 00:00:00')}, {'rank': 110.0, 'country_full': 'Gambia', 'rank_date': '6/14/1994', 'datetime': Timestamp('1994-06-14 00:00:00')}, {'rank': 108.0, 'country_full': 'Gambia', 'rank_date': '7/21/1994', 'datetime': Timestamp('1994-07-21 00:00:00')}, {'rank': 101.0, 'country_full': 'Gambia', 'rank_date': '9/13/1994', 'datetime': Timestamp('1994-09-13 00:00:00')}, {'rank': 107.0, 'country_full': 'Gambia', 'rank_date': '10/25/1994', 'datetime': Timestamp('1994-10-25 00:00:00')}, {'rank': 106.0, 'country_full': 'Gambia', 'rank_date': '11/22/1994', 'datetime': Timestamp('1994-11-22 00:00:00')}, {'rank': 117.0, 'country_full': 'Gambia', 'rank_date': '12/20/1994', 'datetime': Timestamp('1994-12-20 00:00:00')}, {'rank': 111.0, 'country_full': 'Gambia', 'rank_date': '2/20/1995', 'datetime': Timestamp('1995-02-20 00:00:00')}]
# Guinea
# 1995-04-09 00:00:00
# [{'rank': 63.0, 'country_full': 'Guinea', 'rank_date': '12/31/1992', 'datetime': Timestamp('1992-12-31 00:00:00')}, {'rank': 65.0, 'country_full': 'Guinea', 'rank_date': '8/8/1993', 'datetime': Timestamp('1993-08-08 00:00:00')}, {'rank': 60.0, 'country_full': 'Guinea', 'rank_date': '9/23/1993', 'datetime': Timestamp('1993-09-23 00:00:00')}, {'rank': 62.0, 'country_full': 'Guinea', 'rank_date': '11/19/1993', 'datetime': Timestamp('1993-11-19 00:00:00')}, {'rank': 63.0, 'country_full': 'Guinea', 'rank_date': '12/23/1993', 'datetime': Timestamp('1993-12-23 00:00:00')}, {'rank': 64.0, 'country_full': 'Guinea', 'rank_date': '2/15/1994', 'datetime': Timestamp('1994-02-15 00:00:00')}, {'rank': 62.0, 'country_full': 'Guinea', 'rank_date': '3/15/1994', 'datetime': Timestamp('1994-03-15 00:00:00')}, {'rank': 64.0, 'country_full': 'Guinea', 'rank_date': '4/19/1994', 'datetime': Timestamp('1994-04-19 00:00:00')}, {'rank': 62.0, 'country_full': 'Guinea', 'rank_date': '5/17/1994', 'datetime': Timestamp('1994-05-17 00:00:00')}, {'rank': 61.0, 'country_full': 'Guinea', 'rank_date': '6/14/1994', 'datetime': Timestamp('1994-06-14 00:00:00')}, {'rank': 61.0, 'country_full': 'Guinea', 'rank_date': '7/21/1994', 'datetime': Timestamp('1994-07-21 00:00:00')}, {'rank': 61.0, 'country_full': 'Guinea', 'rank_date': '9/13/1994', 'datetime': Timestamp('1994-09-13 00:00:00')}, {'rank': 63.0, 'country_full': 'Guinea', 'rank_date': '10/25/1994', 'datetime': Timestamp('1994-10-25 00:00:00')}, {'rank': 65.0, 'country_full': 'Guinea', 'rank_date': '11/22/1994', 'datetime': Timestamp('1994-11-22 00:00:00')}, {'rank': 66.0, 'country_full': 'Guinea', 'rank_date': '12/20/1994', 'datetime': Timestamp('1994-12-20 00:00:00')}, {'rank': 56.0, 'country_full': 'Guinea', 'rank_date': '2/20/1995', 'datetime': Timestamp('1995-02-20 00:00:00')}]
# Lesotho
# 1995-04-09 00:00:00
# [{'rank': 142.0, 'country_full': 'Lesotho', 'rank_date': '12/31/1992', 'datetime': Timestamp('1992-12-31 00:00:00')}, {'rank': 146.0, 'country_full': 'Lesotho', 'rank_date': '8/8/1993', 'datetime': Timestamp('1993-08-08 00:00:00')}, {'rank': 135.0, 'country_full': 'Lesotho', 'rank_date': '9/23/1993', 'datetime': Timestamp('1993-09-23 00:00:00')}, {'rank': 135.0, 'country_full': 'Lesotho', 'rank_date': '11/19/1993', 'datetime': Timestamp('1993-11-19 00:00:00')}, {'rank': 138.0, 'country_full': 'Lesotho', 'rank_date': '12/23/1993', 'datetime': Timestamp('1993-12-23 00:00:00')}, {'rank': 137.0, 'country_full': 'Lesotho', 'rank_date': '2/15/1994', 'datetime': Timestamp('1994-02-15 00:00:00')}, {'rank': 139.0, 'country_full': 'Lesotho', 'rank_date': '3/15/1994', 'datetime': Timestamp('1994-03-15 00:00:00')}, {'rank': 140.0, 'country_full': 'Lesotho', 'rank_date': '4/19/1994', 'datetime': Timestamp('1994-04-19 00:00:00')}, {'rank': 141.0, 'country_full': 'Lesotho', 'rank_date': '5/17/1994', 'datetime': Timestamp('1994-05-17 00:00:00')}, {'rank': 144.0, 'country_full': 'Lesotho', 'rank_date': '6/14/1994', 'datetime': Timestamp('1994-06-14 00:00:00')}, {'rank': 144.0, 'country_full': 'Lesotho', 'rank_date': '7/21/1994', 'datetime': Timestamp('1994-07-21 00:00:00')}, {'rank': 147.0, 'country_full': 'Lesotho', 'rank_date': '9/13/1994', 'datetime': Timestamp('1994-09-13 00:00:00')}, {'rank': 151.0, 'country_full': 'Lesotho', 'rank_date': '10/25/1994', 'datetime': Timestamp('1994-10-25 00:00:00')}, {'rank': 135.0, 'country_full': 'Lesotho', 'rank_date': '11/22/1994', 'datetime': Timestamp('1994-11-22 00:00:00')}, {'rank': 135.0, 'country_full': 'Lesotho', 'rank_date': '12/20/1994', 'datetime': Timestamp('1994-12-20 00:00:00')}, {'rank': 137.0, 'country_full': 'Lesotho', 'rank_date': '2/20/1995', 'datetime': Timestamp('1995-02-20 00:00:00')}]
# Malawi
# 1995-04-09 00:00:00
# [{'rank': 53.0, 'country_full': 'Malawi', 'rank_date': '12/31/1992', 'datetime': Timestamp('1992-12-31 00:00:00')}, {'rank': 68.0, 'country_full': 'Malawi', 'rank_date': '8/8/1993', 'datetime': Timestamp('1993-08-08 00:00:00')}, {'rank': 68.0, 'country_full': 'Malawi', 'rank_date': '9/23/1993', 'datetime': Timestamp('1993-09-23 00:00:00')}, {'rank': 69.0, 'country_full': 'Malawi', 'rank_date': '10/22/1993', 'datetime': Timestamp('1993-10-22 00:00:00')}, {'rank': 69.0, 'country_full': 'Malawi', 'rank_date': '11/19/1993', 'datetime': Timestamp('1993-11-19 00:00:00')}, {'rank': 67.0, 'country_full': 'Malawi', 'rank_date': '12/23/1993', 'datetime': Timestamp('1993-12-23 00:00:00')}, {'rank': 68.0, 'country_full': 'Malawi', 'rank_date': '2/15/1994', 'datetime': Timestamp('1994-02-15 00:00:00')}, {'rank': 71.0, 'country_full': 'Malawi', 'rank_date': '3/15/1994', 'datetime': Timestamp('1994-03-15 00:00:00')}, {'rank': 81.0, 'country_full': 'Malawi', 'rank_date': '4/19/1994', 'datetime': Timestamp('1994-04-19 00:00:00')}, {'rank': 80.0, 'country_full': 'Malawi', 'rank_date': '5/17/1994', 'datetime': Timestamp('1994-05-17 00:00:00')}, {'rank': 80.0, 'country_full': 'Malawi', 'rank_date': '6/14/1994', 'datetime': Timestamp('1994-06-14 00:00:00')}, {'rank': 85.0, 'country_full': 'Malawi', 'rank_date': '7/21/1994', 'datetime': Timestamp('1994-07-21 00:00:00')}, {'rank': 84.0, 'country_full': 'Malawi', 'rank_date': '9/13/1994', 'datetime': Timestamp('1994-09-13 00:00:00')}, {'rank': 78.0, 'country_full': 'Malawi', 'rank_date': '10/25/1994', 'datetime': Timestamp('1994-10-25 00:00:00')}, {'rank': 81.0, 'country_full': 'Malawi', 'rank_date': '11/22/1994', 'datetime': Timestamp('1994-11-22 00:00:00')}, {'rank': 82.0, 'country_full': 'Malawi', 'rank_date': '12/20/1994', 'datetime': Timestamp('1994-12-20 00:00:00')}, {'rank': 68.0, 'country_full': 'Malawi', 'rank_date': '2/20/1995', 'datetime': Timestamp('1995-02-20 00:00:00')}]
# Morocco
# 1995-04-09 00:00:00
# [{'rank': 41.0, 'country_full': 'Morocco', 'rank_date': '12/31/1992', 'datetime': Timestamp('1992-12-31 00:00:00')}, {'rank': 33.0, 'country_full': 'Morocco', 'rank_date': '8/8/1993', 'datetime': Timestamp('1993-08-08 00:00:00')}, {'rank': 32.0, 'country_full': 'Morocco', 'rank_date': '9/23/1993', 'datetime': Timestamp('1993-09-23 00:00:00')}, {'rank': 30.0, 'country_full': 'Morocco', 'rank_date': '10/22/1993', 'datetime': Timestamp('1993-10-22 00:00:00')}, {'rank': 30.0, 'country_full': 'Morocco', 'rank_date': '11/19/1993', 'datetime': Timestamp('1993-11-19 00:00:00')}, {'rank': 30.0, 'country_full': 'Morocco', 'rank_date': '12/23/1993', 'datetime': Timestamp('1993-12-23 00:00:00')}, {'rank': 28.0, 'country_full': 'Morocco', 'rank_date': '2/15/1994', 'datetime': Timestamp('1994-02-15 00:00:00')}, {'rank': 29.0, 'country_full': 'Morocco', 'rank_date': '3/15/1994', 'datetime': Timestamp('1994-03-15 00:00:00')}, {'rank': 26.0, 'country_full': 'Morocco', 'rank_date': '4/19/1994', 'datetime': Timestamp('1994-04-19 00:00:00')}, {'rank': 30.0, 'country_full': 'Morocco', 'rank_date': '5/17/1994', 'datetime': Timestamp('1994-05-17 00:00:00')}, {'rank': 28.0, 'country_full': 'Morocco', 'rank_date': '6/14/1994', 'datetime': Timestamp('1994-06-14 00:00:00')}, {'rank': 30.0, 'country_full': 'Morocco', 'rank_date': '7/21/1994', 'datetime': Timestamp('1994-07-21 00:00:00')}, {'rank': 30.0, 'country_full': 'Morocco', 'rank_date': '9/13/1994', 'datetime': Timestamp('1994-09-13 00:00:00')}, {'rank': 33.0, 'country_full': 'Morocco', 'rank_date': '10/25/1994', 'datetime': Timestamp('1994-10-25 00:00:00')}, {'rank': 31.0, 'country_full': 'Morocco', 'rank_date': '11/22/1994', 'datetime': Timestamp('1994-11-22 00:00:00')}, {'rank': 33.0, 'country_full': 'Morocco', 'rank_date': '12/20/1994', 'datetime': Timestamp('1994-12-20 00:00:00')}, {'rank': 35.0, 'country_full': 'Morocco', 'rank_date': '2/20/1995', 'datetime': Timestamp('1995-02-20 00:00:00')}]
# Mozambique
# 1995-04-09 00:00:00
# [{'rank': 107.0, 'country_full': 'Mozambique', 'rank_date': '12/31/1992', 'datetime': Timestamp('1992-12-31 00:00:00')}, {'rank': 100.0, 'country_full': 'Mozambique', 'rank_date': '8/8/1993', 'datetime': Timestamp('1993-08-08 00:00:00')}, {'rank': 103.0, 'country_full': 'Mozambique', 'rank_date': '9/23/1993', 'datetime': Timestamp('1993-09-23 00:00:00')}, {'rank': 104.0, 'country_full': 'Mozambique', 'rank_date': '10/22/1993', 'datetime': Timestamp('1993-10-22 00:00:00')}, {'rank': 105.0, 'country_full': 'Mozambique', 'rank_date': '11/19/1993', 'datetime': Timestamp('1993-11-19 00:00:00')}, {'rank': 104.0, 'country_full': 'Mozambique', 'rank_date': '12/23/1993', 'datetime': Timestamp('1993-12-23 00:00:00')}, {'rank': 112.0, 'country_full': 'Mozambique', 'rank_date': '2/15/1994', 'datetime': Timestamp('1994-02-15 00:00:00')}, {'rank': 115.0, 'country_full': 'Mozambique', 'rank_date': '3/15/1994', 'datetime': Timestamp('1994-03-15 00:00:00')}, {'rank': 118.0, 'country_full': 'Mozambique', 'rank_date': '4/19/1994', 'datetime': Timestamp('1994-04-19 00:00:00')}, {'rank': 119.0, 'country_full': 'Mozambique', 'rank_date': '5/17/1994', 'datetime': Timestamp('1994-05-17 00:00:00')}, {'rank': 108.0, 'country_full': 'Mozambique', 'rank_date': '6/14/1994', 'datetime': Timestamp('1994-06-14 00:00:00')}, {'rank': 109.0, 'country_full': 'Mozambique', 'rank_date': '7/21/1994', 'datetime': Timestamp('1994-07-21 00:00:00')}, {'rank': 106.0, 'country_full': 'Mozambique', 'rank_date': '9/13/1994', 'datetime': Timestamp('1994-09-13 00:00:00')}, {'rank': 98.0, 'country_full': 'Mozambique', 'rank_date': '10/25/1994', 'datetime': Timestamp('1994-10-25 00:00:00')}, {'rank': 89.0, 'country_full': 'Mozambique', 'rank_date': '11/22/1994', 'datetime': Timestamp('1994-11-22 00:00:00')}, {'rank': 94.0, 'country_full': 'Mozambique', 'rank_date': '12/20/1994', 'datetime': Timestamp('1994-12-20 00:00:00')}, {'rank': 91.0, 'country_full': 'Mozambique', 'rank_date': '2/20/1995', 'datetime': Timestamp('1995-02-20 00:00:00')}]
# Saint Lucia
# 1995-04-09 00:00:00
# []
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-68-f8646fea7ded> in <module>
# ----> 1 results.apply(home_rank, axis=1)
#
# ~\anaconda3\lib\site-packages\pandas\core\frame.py in apply(self, func, axis, raw, result_type, args, **kwds)
#    7766             kwds=kwds,
#    7767         )
# -> 7768         return op.get_result()
#    7769
#    7770     def applymap(self, func, na_action: Optional[str] = None) -> DataFrame:
#
# ~\anaconda3\lib\site-packages\pandas\core\apply.py in get_result(self)
#     183             return self.apply_raw()
#     184
# --> 185         return self.apply_standard()
#     186
#     187     def apply_empty_result(self):
#
# ~\anaconda3\lib\site-packages\pandas\core\apply.py in apply_standard(self)
#     274
#     275     def apply_standard(self):
# --> 276         results, res_index = self.apply_series_generator()
#     277
#     278         # wrap results
#
# ~\anaconda3\lib\site-packages\pandas\core\apply.py in apply_series_generator(self)
#     288             for i, v in enumerate(series_gen):
#     289                 # ignore SettingWithCopy here in case the user mutates
# --> 290                 results[i] = self.f(v)
#     291                 if isinstance(results[i], ABCSeries):
#     292                     # If we have a view on v, we need to make a copy because
#
# <ipython-input-67-c5de4daa5658> in home_rank(row)
#      21     previous_rankings
#      22
# ---> 23     return previous_rankings[-1]['rank']
#
# IndexError: list index out of range

# %%
rankings[rankings['country_full'].str.contains('Serbia and Montenegro')]
# Out:
#        rank           country_full   rank_date   datetime
# 19486  19.0  Serbia and Montenegro  12/18/2002 2002-12-18
# 19687  19.0  Serbia and Montenegro   1/15/2003 2003-01-15
# 19892  19.0  Serbia and Montenegro   2/19/2003 2003-02-19
# 20093  20.0  Serbia and Montenegro   3/26/2003 2003-03-26
# 20295  22.0  Serbia and Montenegro   4/23/2003 2003-04-23
# 20507  22.0  Serbia and Montenegro   5/21/2003 2003-05-21
# 20698  27.0  Serbia and Montenegro   6/25/2003 2003-06-25
# 20945  33.0  Serbia and Montenegro   7/30/2003 2003-07-30
# 21150  29.0  Serbia and Montenegro   8/27/2003 2003-08-27
# 21348  35.0  Serbia and Montenegro   9/24/2003 2003-09-24
# 21553  32.0  Serbia and Montenegro  10/22/2003 2003-10-22
# 21754  36.0  Serbia and Montenegro  11/19/2003 2003-11-19
# 21951  41.0  Serbia and Montenegro  12/15/2003 2003-12-15
# 22187  41.0  Serbia and Montenegro   1/14/2004 2004-01-14
# 22391  43.0  Serbia and Montenegro   2/18/2004 2004-02-18
# 22558  43.0  Serbia and Montenegro   3/17/2004 2004-03-17
# 22760  44.0  Serbia and Montenegro   4/14/2004 2004-04-14
# 22962  45.0  Serbia and Montenegro   5/12/2004 2004-05-12
# 23168  44.0  Serbia and Montenegro    6/9/2004 2004-06-09
# 23366  48.0  Serbia and Montenegro    7/7/2004 2004-07-07
# 23575  44.0  Serbia and Montenegro    8/4/2004 2004-08-04
# 23746  51.0  Serbia and Montenegro    9/1/2004 2004-09-01
# 23921  55.0  Serbia and Montenegro   10/6/2004 2004-10-06
# 24124  54.0  Serbia and Montenegro  11/10/2004 2004-11-10
# 6487  2001-04-25  Serbia and Montenegro                  Russia         0.0
# 6862  2001-08-15  Serbia and Montenegro           Faroe Islands         2.0
# 6934  2001-09-05  Serbia and Montenegro                Slovenia         1.0
# 6984  2001-10-06  Serbia and Montenegro              Luxembourg         6.0
# 7351  2002-04-17  Serbia and Montenegro               Lithuania         4.0
# 7723  2002-10-16  Serbia and Montenegro                 Finland         2.0
#
#       away_score                    tournament           city      country  \
# 1426         0.0                      Friendly       Belgrade   Yugoslavia
# 1534         2.0                      Friendly       Belgrade   Yugoslavia
# 2086         0.0                      Friendly       Belgrade   Yugoslavia
# 2126         1.0  FIFA World Cup qualification       Belgrade   Yugoslavia
# 2244         0.0  FIFA World Cup qualification       Belgrade   Yugoslavia
# 2656         0.0  FIFA World Cup qualification       Belgrade   Yugoslavia
# 2905         0.0                      Friendly       Belgrade   Yugoslavia
# 3077         1.0  FIFA World Cup qualification       Belgrade   Yugoslavia
# 3173         0.0  FIFA World Cup qualification       Belgrade   Yugoslavia
# 3565         0.0  FIFA World Cup qualification       Belgrade   Yugoslavia
# 3840         1.0                      Friendly       Belgrade   Yugoslavia
# 3893         0.0                      Friendly       Belgrade   Yugoslavia
# 3911         0.0                      Friendly       Lausanne  Switzerland
# 3942         0.0                FIFA World Cup  Saint-Étienne       France
# 4110         1.0                      Friendly            Niš   Yugoslavia
# 4310         0.0       UEFA Euro qualification       Belgrade   Yugoslavia
# 4646         1.0       UEFA Euro qualification       Salonica       Greece
# 4847         0.0       UEFA Euro qualification       Belgrade   Yugoslavia
# 4883         1.0       UEFA Euro qualification       Belgrade   Yugoslavia
# 5316         0.0                      Friendly       Belgrade   Yugoslavia
# 5627         3.0                     UEFA Euro      Charleroi      Belgium
# 5668         4.0                     UEFA Euro         Bruges      Belgium
# 6123         1.0                Millennium Cup         Cochin        India
# 6136         0.0                Millennium Cup         Margao        India
# 6140         0.0                Millennium Cup       Calcutta        India
# 6338         1.0  FIFA World Cup qualification       Belgrade   Yugoslavia
# 6487         1.0  FIFA World Cup qualification       Belgrade   Yugoslavia
# 6862         0.0  FIFA World Cup qualification       Belgrade   Yugoslavia
# 6934         1.0  FIFA World Cup qualification       Belgrade   Yugoslavia
# 6984         2.0  FIFA World Cup qualification       Belgrade   Yugoslavia
# 7351         1.0                      Friendly      Smederevo   Yugoslavia
# 7723         0.0       UEFA Euro qualification       Belgrade   Yugoslavia
#
#       neutral  home_rank  away_rank   datetime
# 1426    False          0          0 1995-03-31
# 1534    False          0          0 1995-05-31
# 2086    False          0          0 1996-03-27
# 2126     True          0          0 1996-04-24
# 2244     True          0          0 1996-06-02
# 2656     True          0          0 1996-11-10
# 2905    False          0          0 1997-03-12
# 3077     True          0          0 1997-04-30
# 3173     True          0          0 1997-06-08
# 3565     True          0          0 1997-11-15
# 3840    False          0          0 1998-04-22
# 3893    False          0          0 1998-05-29
# 3911     True          0          0 1998-06-03
# 3942     True          0          0 1998-06-14
# 4110    False          0          0 1998-09-02
# 4310    False          0          0 1998-11-18
# 4646     True          0          0 1999-06-08
# 4847    False          0          0 1999-08-18
# 4883    False          0          0 1999-09-05
# 5316    False          0          0 2000-03-28
# 5627     True          0          0 2000-06-13
# 5668     True          0          0 2000-06-21
# 6123     True          0          0 2001-01-14
# 6136     True          0          0 2001-01-20
# 6140     True          0          0 2001-01-23
# 6338     True          0          0 2001-03-24
# 6487     True          0          0 2001-04-25
# 6862     True          0          0 2001-08-15
# 6934     True          0          0 2001-09-05
# 6984     True          0          0 2001-10-06
# 7351    False          0          0 2002-04-17
# 7723    False          0          0 2002-10-16

# %%
results[results['home_team'] == 'Sint Maarten'].shape
